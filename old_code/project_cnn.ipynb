# %%
import torch
import torch.utils.data
from torch.autograd import Variable
import torch.nn as nn
import torch.optim as optim
import numpy as np
import h5py
from data_utils import get_data
import matplotlib.pyplot as plt

# %%
# Load data from all .mat files, combine them, eliminate EOG signals, shuffle and 
# seperate training data, validation data and testing data.
# Also do mean subtraction on x.

data = get_data('project_datasets',num_validation=100, num_test=50)
for k in data.keys():
    print('{}: {} '.format(k, data[k].shape))
# Out:
# X_train: (2408, 22, 1000)
# y_train: (2408,)
# X_val: (100, 22, 1000)
# y_val: (100,)
# X_test: (50, 22, 1000)
# y_test: (50,)

# %%
# class flatten to connect to FC layer
class Flatten(nn.Module):
    def forward(self, x):
        N, C, H = x.size() # read in N, C, H
        return x.view(N, -1)

# %%
# turn x and y into torch type tensor

N_train, C_train, H_train = data.get('X_train').shape
N_val, C_val, H_val = data.get('X_val').shape
N_test, C_test, H_test = data.get('X_test').shape

dtype = torch.FloatTensor

X_train = Variable(torch.Tensor(data.get('X_train'))).type(dtype)
y_train = Variable(torch.Tensor(data.get('y_train'))).type(torch.LongTensor)
X_val = Variable(torch.Tensor(data.get('X_val'))).type(dtype)
y_val = Variable(torch.Tensor(data.get('y_val'))).type(torch.LongTensor)
X_test = Variable(torch.Tensor(data.get('X_test'))).type(dtype)
y_test = Variable(torch.Tensor(data.get('y_test'))).type(torch.LongTensor)

# %%
# set up sequential model

model = nn.Sequential(
                      nn.Conv1d(22, 10, kernel_size=12, stride=4),
                      nn.ReLU(inplace=True),
                      nn.Dropout(p=0.5),
                      nn.BatchNorm1d(num_features=10),
                      nn.MaxPool1d(kernel_size=4, stride=4),
                      Flatten(),
                      nn.Linear(620, 20),
                      nn.ReLU(inplace=True),
                      nn.Linear(20, 4)
)

model.type(dtype)
loss_fn = nn.CrossEntropyLoss().type(dtype)
optimizer = optim.Adam(model.parameters(), lr=1e-4)

# %%
# train through several iterations
num_epoch = 100
batch_size = 80
step = np.arange(0,N_train,batch_size)
#step = np.append(step,N_train) #discard some data

loss_his = []
train_accu_his = []
val_accu_his = []

for epoch in range(num_epoch):
    for t in range(step.shape[0]-1):

        # calculate training loss
        y_train_pred = model(X_train[step[t]:step[t+1],:,:])
        loss = loss_fn(y_train_pred, y_train[step[t]:step[t+1]])

        # backpropagation
        model.zero_grad()
        loss.backward()

        # update parameters
        optimizer.step()
        
    # calculate predicted value for validation
    y_val_pred = model(X_val)

    # training loss
    print('Epoch ', epoch, ', loss is ', loss.data.numpy())
    _, y_pred = torch.max(y_train_pred,1)
    loss_his.append(loss.data.numpy())
    
    # training accuracy
    train_accu = np.mean(y_pred.data.numpy() == 
                                       y_train.data[step[t]:step[t+1]].numpy())
    print('Training accuracy', train_accu)
    train_accu_his.append(train_accu)

    # validation accuracy    
    _, y_pred = torch.max(y_val_pred,1)
    val_accu = np.mean(y_pred.data.numpy() ==  y_val.data.numpy())
    print('Validation accuracy', val_accu, '\n')   
    val_accu_his.append(val_accu)
# Out:
# Epoch  0 , loss is  [ 1.3916899]
# Training accuracy 0.2375
# Validation accuracy 0.26
#
# Epoch  1 , loss is  [ 1.37960505]
# Training accuracy 0.2625
# Validation accuracy 0.28
#
# Epoch  2 , loss is  [ 1.38793576]
# Training accuracy 0.3
# Validation accuracy 0.26
#
# Epoch  3 , loss is  [ 1.37578607]
# Training accuracy 0.3
# Validation accuracy 0.32
#
# Epoch  4 , loss is  [ 1.3439728]
# Training accuracy 0.35
# Validation accuracy 0.23
#
# Epoch  5 , loss is  [ 1.3512131]
# Training accuracy 0.3375
# Validation accuracy 0.23
#
# Epoch  6 , loss is  [ 1.33631802]
# Training accuracy 0.375
# Validation accuracy 0.31
#
# Epoch  7 , loss is  [ 1.33932757]
# Training accuracy 0.325
# Validation accuracy 0.31
#
# Epoch  8 , loss is  [ 1.28917289]
# Training accuracy 0.475
# Validation accuracy 0.26
#
# Epoch  9 , loss is  [ 1.29345179]
# Training accuracy 0.45
# Validation accuracy 0.3
#
# Epoch  10 , loss is  [ 1.3039968]
# Training accuracy 0.4
# Validation accuracy 0.35
#
# Epoch  11 , loss is  [ 1.26906168]
# Training accuracy 0.4875
# Validation accuracy 0.33
#
# Epoch  12 , loss is  [ 1.2684958]
# Training accuracy 0.4375
# Validation accuracy 0.36
#
# Epoch  13 , loss is  [ 1.22697139]
# Training accuracy 0.4875
# Validation accuracy 0.37
#
# Epoch  14 , loss is  [ 1.27008629]
# Training accuracy 0.4125
# Validation accuracy 0.32
#
# Epoch  15 , loss is  [ 1.20067871]
# Training accuracy 0.4625
# Validation accuracy 0.28
#
# Epoch  16 , loss is  [ 1.19700301]
# Training accuracy 0.4875
# Validation accuracy 0.36
#
# Epoch  17 , loss is  [ 1.20671678]
# Training accuracy 0.5
# Validation accuracy 0.36
#
# Epoch  18 , loss is  [ 1.154616]
# Training accuracy 0.4875
# Validation accuracy 0.41
#
# Epoch  19 , loss is  [ 1.17414105]
# Training accuracy 0.45
# Validation accuracy 0.4
#
# Epoch  20 , loss is  [ 1.14748287]
# Training accuracy 0.475
# Validation accuracy 0.45
#
# Epoch  21 , loss is  [ 1.1212728]
# Training accuracy 0.5
# Validation accuracy 0.39
#
# Epoch  22 , loss is  [ 1.14192271]
# Training accuracy 0.5375
# Validation accuracy 0.43
#
# Epoch  23 , loss is  [ 1.09406376]
# Training accuracy 0.6
# Validation accuracy 0.47
#
# Epoch  24 , loss is  [ 1.04665339]
# Training accuracy 0.575
# Validation accuracy 0.45
#
# Epoch  25 , loss is  [ 1.05187285]
# Training accuracy 0.6125
# Validation accuracy 0.44
#
# Epoch  26 , loss is  [ 1.024719]
# Training accuracy 0.625
# Validation accuracy 0.43
#
# Epoch  27 , loss is  [ 1.04255319]
# Training accuracy 0.6
# Validation accuracy 0.49
#
# Epoch  28 , loss is  [ 1.05288982]
# Training accuracy 0.5875
# Validation accuracy 0.43
#
# Epoch  29 , loss is  [ 1.01481843]
# Training accuracy 0.6125
# Validation accuracy 0.43
#
# Epoch  30 , loss is  [ 0.99861687]
# Training accuracy 0.575
# Validation accuracy 0.51
#
# Epoch  31 , loss is  [ 0.97080022]
# Training accuracy 0.6625
# Validation accuracy 0.47
#
# Epoch  32 , loss is  [ 0.96540278]
# Training accuracy 0.6375
# Validation accuracy 0.47
#
# Epoch  33 , loss is  [ 0.97241819]
# Training accuracy 0.6375
# Validation accuracy 0.45
#
# Epoch  34 , loss is  [ 0.9463414]
# Training accuracy 0.625
# Validation accuracy 0.46
#
# Epoch  35 , loss is  [ 0.93506175]
# Training accuracy 0.65
# Validation accuracy 0.43
#
# Epoch  36 , loss is  [ 0.91551077]
# Training accuracy 0.6
# Validation accuracy 0.49
#
# Epoch  37 , loss is  [ 0.95127285]
# Training accuracy 0.625
# Validation accuracy 0.5
#
# Epoch  38 , loss is  [ 0.94768077]
# Training accuracy 0.625
# Validation accuracy 0.48
#
# Epoch  39 , loss is  [ 0.94170606]
# Training accuracy 0.575
# Validation accuracy 0.44
#
# Epoch  40 , loss is  [ 0.91708851]
# Training accuracy 0.675
# Validation accuracy 0.54
#
# Epoch  41 , loss is  [ 0.89841855]
# Training accuracy 0.625
# Validation accuracy 0.54
#
# Epoch  42 , loss is  [ 0.93367559]
# Training accuracy 0.625
# Validation accuracy 0.49
#
# Epoch  43 , loss is  [ 0.8441745]
# Training accuracy 0.7125
# Validation accuracy 0.52
#
# Epoch  44 , loss is  [ 0.8990739]
# Training accuracy 0.6375
# Validation accuracy 0.49
#
# Epoch  45 , loss is  [ 0.87131566]
# Training accuracy 0.675
# Validation accuracy 0.51
#
# Epoch  46 , loss is  [ 0.85906899]
# Training accuracy 0.675
# Validation accuracy 0.58
#
# Epoch  47 , loss is  [ 0.80525303]
# Training accuracy 0.675
# Validation accuracy 0.5
#
# Epoch  48 , loss is  [ 0.83376855]
# Training accuracy 0.7
# Validation accuracy 0.47
#
# Epoch  49 , loss is  [ 0.82932711]
# Training accuracy 0.7
# Validation accuracy 0.53
#
# Epoch  50 , loss is  [ 0.84372437]
# Training accuracy 0.6375
# Validation accuracy 0.5
#
# Epoch  51 , loss is  [ 0.80232972]
# Training accuracy 0.7125
# Validation accuracy 0.52
#
# Epoch  52 , loss is  [ 0.72805947]
# Training accuracy 0.75
# Validation accuracy 0.48
#
# Epoch  53 , loss is  [ 0.74495894]
# Training accuracy 0.7
# Validation accuracy 0.54
#
# Epoch  54 , loss is  [ 0.79985249]
# Training accuracy 0.6875
# Validation accuracy 0.5
#
# Epoch  55 , loss is  [ 0.81161898]
# Training accuracy 0.6875
# Validation accuracy 0.52
#
# Epoch  56 , loss is  [ 0.79486036]
# Training accuracy 0.6625
# Validation accuracy 0.49
#
# Epoch  57 , loss is  [ 0.80732262]
# Training accuracy 0.65
# Validation accuracy 0.55
#
# Epoch  58 , loss is  [ 0.7523874]
# Training accuracy 0.7
# Validation accuracy 0.51
#
# Epoch  59 , loss is  [ 0.81476068]
# Training accuracy 0.6875
# Validation accuracy 0.55
#
# Epoch  60 , loss is  [ 0.77282268]
# Training accuracy 0.7
# Validation accuracy 0.51
#
# Epoch  61 , loss is  [ 0.78622752]
# Training accuracy 0.675
# Validation accuracy 0.57
#
# Epoch  62 , loss is  [ 0.78071553]
# Training accuracy 0.7
# Validation accuracy 0.58
#
# Epoch  63 , loss is  [ 0.76811725]
# Training accuracy 0.7625
# Validation accuracy 0.52
#
# Epoch  64 , loss is  [ 0.76923335]
# Training accuracy 0.725
# Validation accuracy 0.55
#
# Epoch  65 , loss is  [ 0.74003816]
# Training accuracy 0.7
# Validation accuracy 0.59
#
# Epoch  66 , loss is  [ 0.72371089]
# Training accuracy 0.7
# Validation accuracy 0.55
#
# Epoch  67 , loss is  [ 0.66835731]
# Training accuracy 0.8
# Validation accuracy 0.61
#
# Epoch  68 , loss is  [ 0.68647063]
# Training accuracy 0.7
# Validation accuracy 0.59
#
# Epoch  69 , loss is  [ 0.68224174]
# Training accuracy 0.75
# Validation accuracy 0.53
#
# Epoch  70 , loss is  [ 0.74927521]
# Training accuracy 0.7125
# Validation accuracy 0.52
#
# Epoch  71 , loss is  [ 0.67370039]
# Training accuracy 0.75
# Validation accuracy 0.54
#
# Epoch  72 , loss is  [ 0.68785566]
# Training accuracy 0.7375
# Validation accuracy 0.49
#
# Epoch  73 , loss is  [ 0.75155371]
# Training accuracy 0.7125
# Validation accuracy 0.53
#
# Epoch  74 , loss is  [ 0.78426987]
# Training accuracy 0.675
# Validation accuracy 0.65
#
# Epoch  75 , loss is  [ 0.74919492]
# Training accuracy 0.65
# Validation accuracy 0.56
#
# Epoch  76 , loss is  [ 0.71706682]
# Training accuracy 0.75
# Validation accuracy 0.6
#
# Epoch  77 , loss is  [ 0.73664939]
# Training accuracy 0.7125
# Validation accuracy 0.59
#
# Epoch  78 , loss is  [ 0.67748833]
# Training accuracy 0.7625
# Validation accuracy 0.6
#
# Epoch  79 , loss is  [ 0.70414811]
# Training accuracy 0.75
# Validation accuracy 0.56
#
# Epoch  80 , loss is  [ 0.63189143]
# Training accuracy 0.7625
# Validation accuracy 0.54
#
# Epoch  81 , loss is  [ 0.6363079]
# Training accuracy 0.7625
# Validation accuracy 0.54
#
# Epoch  82 , loss is  [ 0.66619825]
# Training accuracy 0.7625
# Validation accuracy 0.54
#
# Epoch  83 , loss is  [ 0.69979596]
# Training accuracy 0.725
# Validation accuracy 0.59
#
# Epoch  84 , loss is  [ 0.66378629]
# Training accuracy 0.775
# Validation accuracy 0.57
#
# Epoch  85 , loss is  [ 0.62242186]
# Training accuracy 0.75
# Validation accuracy 0.62
#
# Epoch  86 , loss is  [ 0.5874148]
# Training accuracy 0.775
# Validation accuracy 0.6
#
# Epoch  87 , loss is  [ 0.65616506]
# Training accuracy 0.7375
# Validation accuracy 0.57
#
# Epoch  88 , loss is  [ 0.60221809]
# Training accuracy 0.75
# Validation accuracy 0.58
#
# Epoch  89 , loss is  [ 0.70556891]
# Training accuracy 0.6625
# Validation accuracy 0.58
#
# Epoch  90 , loss is  [ 0.65978163]
# Training accuracy 0.7625
# Validation accuracy 0.56
#
# Epoch  91 , loss is  [ 0.59097421]
# Training accuracy 0.8
# Validation accuracy 0.58
#
# Epoch  92 , loss is  [ 0.69299185]
# Training accuracy 0.7125
# Validation accuracy 0.58
#
# Epoch  93 , loss is  [ 0.74683803]
# Training accuracy 0.7375
# Validation accuracy 0.64
#
# Epoch  94 , loss is  [ 0.62423694]
# Training accuracy 0.7875
# Validation accuracy 0.56
#
# Epoch  95 , loss is  [ 0.65591848]
# Training accuracy 0.7
# Validation accuracy 0.62
# Epoch  96 , loss is  [ 0.64680398]
# Training accuracy 0.7625
# Validation accuracy 0.56
#
# Epoch  97 , loss is  [ 0.61892861]
# Training accuracy 0.7625
# Validation accuracy 0.52
#
# Epoch  98 , loss is  [ 0.71597588]
# Training accuracy 0.6875
# Validation accuracy 0.61
#
# Epoch  99 , loss is  [ 0.60675442]
# Training accuracy 0.775
# Validation accuracy 0.53

# %%
# plot training and validation history
plt.subplot(2, 1, 1)
plt.plot(loss_his, 'o')
plt.xlabel('epoch')
plt.ylabel('loss')

plt.subplot(2,1,2)
plt.plot(train_accu_his, '-o')
plt.plot(val_accu_his, '-o')
plt.legend(['train','val'], loc='upper left')
plt.xlabel('epoch')
plt.ylabel('accuracy')

plt.show()

# %%
# test set
y_test_pred = model(X_test)
  
_, y_pred = torch.max(y_test_pred,1)
test_accu = np.mean(y_pred.data.numpy() ==  y_test.data.numpy())
print('Test accuracy', test_accu, '\n')
# Out:
# Test accuracy 0.68
