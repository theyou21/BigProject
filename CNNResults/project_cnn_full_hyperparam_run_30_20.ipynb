# %%
import torch
import torch.utils.data
from torch.autograd import Variable
import torch.nn as nn
import torch.optim as optim
import numpy as np
import h5py
from data_utils import get_data
import matplotlib.pyplot as plt
from solver_pytorch import Solver

# %%
# Load data from all .mat files, combine them, eliminate EOG signals, shuffle and 
# seperate training data, validation data and testing data.
# Also do mean subtraction on x.

data = get_data('../project_datasets',num_validation=100, num_test=100)
for k in data.keys():
    print('{}: {} '.format(k, data[k].shape))
# Out:
# X_train: (2358, 22, 1000)
# y_train: (2358,)
# X_val: (100, 22, 1000)
# y_val: (100,)
# X_test: (100, 22, 1000)
# y_test: (100,)

# %%
# class flatten to connect to FC layer
class Flatten(nn.Module):
    def forward(self, x):
        N, C, H = x.size() # read in N, C, H
        return x.view(N, -1)

# %%
# turn x and y into torch type tensor

dtype = torch.FloatTensor

X_train = Variable(torch.Tensor(data.get('X_train'))).type(dtype)
y_train = Variable(torch.Tensor(data.get('y_train'))).type(torch.IntTensor)
X_val = Variable(torch.Tensor(data.get('X_val'))).type(dtype)
y_val = Variable(torch.Tensor(data.get('y_val'))).type(torch.IntTensor)
X_test = Variable(torch.Tensor(data.get('X_test'))).type(dtype)
y_test = Variable(torch.Tensor(data.get('y_test'))).type(torch.IntTensor)

# %%
# train a 1D convolutional neural network
# optimize hyper parameters
best_model = None
parameters =[] # a list of dictionaries
parameter = {} # a dictionary
best_params = {} # a dictionary
best_val_acc = 0.0

# hyper parameters in model
filter_nums = [30]

filter_sizes = [20]
pool_sizes = [4]

# hyper parameters in solver
batch_sizes = [100]
lrs = [5e-4]

for filter_num in filter_nums:
    for filter_size in filter_sizes:
        for pool_size in pool_sizes:
            linear_size = int((X_test.shape[2]-filter_size)/4)+1
            linear_size = int((linear_size-pool_size)/pool_size)+1
            linear_size *= filter_num
            for batch_size in batch_sizes:
                for lr in lrs:
                    model = nn.Sequential(
                        nn.Conv1d(22, filter_num, kernel_size=filter_size, stride=4),
                        nn.ReLU(inplace=True),
                        nn.Dropout(p=0.5),
                        nn.BatchNorm1d(num_features=filter_num),
                        nn.MaxPool1d(kernel_size=pool_size, stride=pool_size),
                        Flatten(),
                        nn.Linear(linear_size, 20),
                        nn.ReLU(inplace=True),
                        nn.Linear(20, 4)
                    )

                    model.type(dtype)

                    solver = Solver(model, data,
                                    lr = lr, batch_size=batch_size,
                                    verbose=True, print_every=50)

                    solver.train()

                    # save training results and parameters of neural networks
                    parameter['filter_num'] = filter_num
                    parameter['filter_size'] = filter_size
                    parameter['pool_size'] = pool_size
                    parameter['batch_size'] = batch_size
                    parameter['lr'] = lr
                    parameters.append(parameter)

                    print('Accuracy on the validation set: ', solver.best_val_acc)
                    print('parameters of the best model:')
                    print(parameter)

                    if solver.best_val_acc > best_val_acc:
                        best_val_acc = solver.best_val_acc
                        best_model = model
                        best_solver = solver
                        best_params = parameter
# Out:
# The history saving thread hit an unexpected error (OperationalError('disk I/O error',)).History will not be written to the database.
# (Iteration 1 / 1150) loss: 1.433472
# (Epoch 0 / 50) train acc: 0.259118; val_acc: 0.160000
# (Epoch 1 / 50) train acc: 0.362595; val_acc: 0.290000
# (Epoch 2 / 50) train acc: 0.414334; val_acc: 0.300000
# (Iteration 51 / 1150) loss: 1.277170
# (Epoch 3 / 50) train acc: 0.490670; val_acc: 0.360000
# (Epoch 4 / 50) train acc: 0.526293; val_acc: 0.410000
# (Iteration 101 / 1150) loss: 1.059054
# (Epoch 5 / 50) train acc: 0.595420; val_acc: 0.440000
# (Epoch 6 / 50) train acc: 0.616624; val_acc: 0.510000
# (Iteration 151 / 1150) loss: 0.954190
# (Epoch 7 / 50) train acc: 0.642918; val_acc: 0.510000
# (Epoch 8 / 50) train acc: 0.673876; val_acc: 0.570000
# (Iteration 201 / 1150) loss: 0.764921
# (Epoch 9 / 50) train acc: 0.700170; val_acc: 0.590000
# (Epoch 10 / 50) train acc: 0.710348; val_acc: 0.590000
# (Iteration 251 / 1150) loss: 0.679577
# (Epoch 11 / 50) train acc: 0.726463; val_acc: 0.570000
# (Epoch 12 / 50) train acc: 0.756573; val_acc: 0.580000
# (Epoch 13 / 50) train acc: 0.762511; val_acc: 0.600000
# (Iteration 301 / 1150) loss: 0.647958
# (Epoch 14 / 50) train acc: 0.787532; val_acc: 0.630000
# (Epoch 15 / 50) train acc: 0.790500; val_acc: 0.620000
# (Iteration 351 / 1150) loss: 0.693387
# (Epoch 16 / 50) train acc: 0.796014; val_acc: 0.610000
# (Epoch 17 / 50) train acc: 0.809584; val_acc: 0.630000
# (Iteration 401 / 1150) loss: 0.540300
# (Epoch 18 / 50) train acc: 0.818914; val_acc: 0.660000
# (Epoch 19 / 50) train acc: 0.820187; val_acc: 0.620000
# (Iteration 451 / 1150) loss: 0.556050
# (Epoch 20 / 50) train acc: 0.820611; val_acc: 0.620000
# (Epoch 21 / 50) train acc: 0.833333; val_acc: 0.600000
# (Iteration 501 / 1150) loss: 0.429502
# (Epoch 22 / 50) train acc: 0.857506; val_acc: 0.650000
# (Epoch 23 / 50) train acc: 0.854962; val_acc: 0.650000
# (Iteration 551 / 1150) loss: 0.349778
# (Epoch 24 / 50) train acc: 0.853265; val_acc: 0.650000
# (Epoch 25 / 50) train acc: 0.876590; val_acc: 0.670000
# (Epoch 26 / 50) train acc: 0.865564; val_acc: 0.630000
# (Iteration 601 / 1150) loss: 0.400874
# (Epoch 27 / 50) train acc: 0.871925; val_acc: 0.690000
# (Epoch 28 / 50) train acc: 0.875742; val_acc: 0.680000
# (Iteration 651 / 1150) loss: 0.363448
# (Epoch 29 / 50) train acc: 0.886768; val_acc: 0.700000
# (Epoch 30 / 50) train acc: 0.896522; val_acc: 0.660000
# (Iteration 701 / 1150) loss: 0.294993
# (Epoch 31 / 50) train acc: 0.890585; val_acc: 0.670000
# (Epoch 32 / 50) train acc: 0.897795; val_acc: 0.710000
# (Iteration 751 / 1150) loss: 0.265709
# (Epoch 33 / 50) train acc: 0.886344; val_acc: 0.680000
# (Epoch 34 / 50) train acc: 0.893554; val_acc: 0.700000
# (Iteration 801 / 1150) loss: 0.266182
# (Epoch 35 / 50) train acc: 0.891009; val_acc: 0.680000
# (Epoch 36 / 50) train acc: 0.907125; val_acc: 0.670000
# (Iteration 851 / 1150) loss: 0.277186
# (Epoch 37 / 50) train acc: 0.906277; val_acc: 0.690000
# (Epoch 38 / 50) train acc: 0.909245; val_acc: 0.660000
# (Epoch 39 / 50) train acc: 0.915606; val_acc: 0.690000
# (Iteration 901 / 1150) loss: 0.228565
# (Epoch 40 / 50) train acc: 0.910093; val_acc: 0.670000
# (Epoch 41 / 50) train acc: 0.923240; val_acc: 0.640000
# (Iteration 951 / 1150) loss: 0.298784
# (Epoch 42 / 50) train acc: 0.916879; val_acc: 0.670000
# (Epoch 43 / 50) train acc: 0.922816; val_acc: 0.690000
# (Iteration 1001 / 1150) loss: 0.283511
# (Epoch 44 / 50) train acc: 0.925360; val_acc: 0.690000
# (Epoch 45 / 50) train acc: 0.935963; val_acc: 0.680000
# (Iteration 1051 / 1150) loss: 0.234836
# (Epoch 46 / 50) train acc: 0.924512; val_acc: 0.630000
# (Epoch 47 / 50) train acc: 0.934266; val_acc: 0.610000
# (Iteration 1101 / 1150) loss: 0.217802
# (Epoch 48 / 50) train acc: 0.932146; val_acc: 0.670000
# (Epoch 49 / 50) train acc: 0.936811; val_acc: 0.710000
# (Epoch 50 / 50) train acc: 0.935963; val_acc: 0.660000
# Accuracy on the validation set:  0.71
# parameters of the best model:
# {'filter_num': 30, 'filter_size': 20, 'pool_size': 4, 'batch_size': 100, 'lr': 0.0005}

# %%
# Plot the loss function and train / validation accuracies of the best model
plt.subplot(2,1,1)
plt.plot(best_solver.loss_history)
plt.title('Training loss history')
plt.xlabel('Iteration')
plt.ylabel('Training loss')

plt.subplot(2,1,2)
plt.plot(best_solver.train_acc_history, '-o', label='train accuracy')
plt.plot(best_solver.val_acc_history, '-o', label='validation accuracy')
plt.xlabel('Iteration')
plt.ylabel('Accuracies')
plt.legend(loc='upper center', ncol=4)

plt.gcf().set_size_inches(10, 10)
plt.show()

print('Accuracy on the validation set: ', best_val_acc)
print('parameters of the best model:')
print(best_params)
# Out:
# Accuracy on the validation set:  0.71
# parameters of the best model:
# {'filter_num': 30, 'filter_size': 20, 'pool_size': 4, 'batch_size': 100, 'lr': 0.0005}

# %%
# test set
y_test_pred = model(X_test)
  
_, y_pred = torch.max(y_test_pred,1)
test_accu = np.mean(y_pred.data.numpy() ==  y_test.data.numpy())
print('Test accuracy', test_accu, '\n')
# Out:
# Test accuracy 0.6
