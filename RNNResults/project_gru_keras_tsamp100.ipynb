# %%
from keras.models import Sequential
from keras.layers import LSTM, GRU, Dense, Dropout, TimeDistributed, BatchNormalization, Flatten, Activation
from keras import regularizers
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.models import load_model
import numpy as np
import h5py
import matplotlib.pyplot as plt
from data_utils import get_data
from sklearn import preprocessing
from functools import reduce
from scipy.fftpack import dct, idct
from scipy import signal
# Out:
# Using TensorFlow backend.

# %%
# Load data from all .mat files, combine them, eliminate EOG signals, shuffle and 
# seperate training data, validation data and testing data.
# Also do mean subtraction on x.

data = get_data('project_datasets',num_validation=0, num_test=100, subtract_mean=False, subtract_axis=1,
                transpose=True)
for k in data.keys():
    print('{}: {} '.format(k, data[k].shape))
# Out:
# X_train: (2458, 1000, 22)
# y_train: (2458,)
# X_val: (0, 1000, 22)
# y_val: (0,)
# X_test: (100, 1000, 22)
# y_test: (100,)

# %%
# substract data from list
X_train = data.get('X_train')
y_train = data.get('y_train')
#X_val = data.get('X_val')
#y_val = data.get('y_val')
X_test = data.get('X_test')
y_test = data.get('y_test')

# get data dimension
N_train, T_train, C_train = data.get('X_train').shape
N_val, T_val, C_val = data.get('X_val').shape
N_test, T_test, C_test = data.get('X_test').shape

# add dummy zeros for y classification
lb = preprocessing.LabelBinarizer()
lb.fit([0, 1, 2, 3,])
lb.classes_
y_train = lb.transform(y_train)
if (N_val > 0): y_val = lb.transform(y_val)
y_test = lb.transform(y_test)

# %%
# Filtering through FFT(discrete cosine transform)

def filter(x, low=0, high=1, plot=False):
    N = x.shape[0]
    t = np.linspace(0,N,N)
    y = dct(x, norm='ortho')
    window = np.zeros(N)
    window[int(low*N):int(high*N)] = 1
    yr = idct(y*window, norm='ortho')
    sum(abs(x-yr)**2) / sum(abs(x)**2)
    if plot:
        plt.plot(t, x, '-b')
        plt.plot(t, yr, 'r')
    return x

# Filter band
low_freq = 0.02
high_freq = 0.4

for i in np.arange(N_train):
    for j in np.arange(C_train):
       X_train[i,:,j]= filter(X_train[i,:,j],low_freq,high_freq)
for i in np.arange(N_val):
    for j in arange(C_val):
       X_val[i,:,j]= filter(X_val[i,:,j],low_freq,high_freq)
    
for i in np.arange(N_test):
    for j in np.arange(C_test):
       X_test[i,:,j]= filter(X_test[i,:,j],low_freq,high_freq)

# %%
# Downsampling in time through FFT

t_sample = 100
X_train_sub = signal.resample(X_train,t_sample,axis=1)
if (N_val > 0): X_val_sub = signal.resample(X_val,t_sample,axis=1)
X_test_sub = signal.resample(X_test,t_sample,axis=1)

# show a downsampling example
plt.plot(np.linspace(0,1,T_train),X_train[5,:,5],'-b')
plt.plot(np.linspace(0,1,t_sample),X_train_sub[5,:,5],'-r')

# %%
print(X_train_sub.shape)
# Out:
# (2458, 100, 22)

# %%
# # normalize data across the time sequence dimension only
# scaler = preprocessing.MinMaxScaler()
# for i in range(N_train):
#     scaler.fit(X_train[i,:,:])
#     X_train[i,:,:] = scaler.transform(X_train[i,:,:])
    
# for i in range(N_val):
#     scaler.fit(X_val[i,:,:])
#     X_val[i,:,:] = scaler.transform(X_val[i,:,:])

# %%
# def downsample(data, mul=10, enableTrunc = False):
#     assert data.shape[0] % mul == 0 or  enableTrunc, "Can't downsample without data truncation.\
#                                                 \n Set another value of mul or set enableTrunc = True"
#     outdata = []
#     for i in range(data.shape[0]//mul):
#         outdata.append(np.mean(data[i*mul:(i+1)*mul,...], axis=0, keepdims=True))
#     outdata = reduce(lambda a,b: np.append(a,b,0), outdata)
    
#     return outdata
# span = 2
# X_train_sub = np.expand_dims(downsample(X_train[0,:,:], mul=span),axis=0)
# for n in np.arange(1,X_train.shape[0]):
#     X_train_sub = np.append(X_train_sub,
#                             np.expand_dims(downsample(X_train[n,:,:], mul=span),axis=0),axis=0)

# X_val_sub = np.expand_dims(downsample(X_val[0,:,:], mul=span),axis=0)
# for n in np.arange(1,X_val.shape[0]):
#     X_val_sub = np.append(X_val_sub,
#                             np.expand_dims(downsample(X_val[n,:,:], mul=span),axis=0),axis=0)

# print('X_train_sub: ', X_train_sub.shape)
# print('X_val_sub: ', X_val_sub.shape)

# %%
# Expected input shape: ([batch_size], timesteps, data_dim)
# Note that we have to provide the full batch_input_shape if the network is stateful.
# the sample of index i in batch k is the follow-up for the sample i in batch k-1.

# perhaps should try masking layer

data_dim = C_train
seq_split = 1 # Set to one when using FFT to down sample
seq_len = int(X_train_sub.shape[1]*seq_split)
timesteps = seq_len
num_classes = 4
batch_size = 200
num_epoch = 150

model = Sequential()
#1
model.add(GRU(200, return_sequences=True, stateful=False,
          recurrent_dropout=0.6, dropout = 0.6, input_shape=(timesteps, data_dim)))

#2
model.add(GRU(100, return_sequences=True, stateful=False,
          recurrent_dropout=0.6, dropout = 0.6))

#3
model.add(GRU(50, return_sequences=True, stateful=False,
          recurrent_dropout=0.6, dropout = 0.6))
model.add(Flatten())

#4
model.add(Dense(100))
model.add(BatchNormalization(axis=-1))
model.add(Activation('relu'))
model.add(Dropout(0.5))

#5
model.add(Dense(num_classes, activation='softmax'))

model.compile(loss='categorical_crossentropy',
              optimizer='rmsprop',
              metrics=['accuracy'])

# define early stopping callback
earlystop = EarlyStopping(monitor='val_loss', min_delta=0.001, patience=70, mode='auto')

# saves the model weights after each epoch if the validation loss decreased
checkpointer = ModelCheckpoint(filepath='GRU_model.hdf5', monitor='val_acc', verbose=1, save_best_only=True)

callbacks_list = [earlystop, checkpointer]

# %%
history = model.fit(X_train_sub[:,:seq_len,:], y_train,
                    batch_size=batch_size, epochs=num_epoch, shuffle=True,
                    validation_split = 0.15, callbacks=callbacks_list)
# Out:
# Train on 2089 samples, validate on 369 samples
# Epoch 1/150
# 2089/2089 [==============================] - 8s 4ms/step - loss: 1.9213 - acc: 0.2642 - val_loss: 1.3808 - val_acc: 0.2954
#
# Epoch 00001: val_acc improved from -inf to 0.29539, saving model to GRU_model.hdf5
# Epoch 2/150
# 2089/2089 [==============================] - 6s 3ms/step - loss: 1.7476 - acc: 0.2657 - val_loss: 1.4147 - val_acc: 0.3225
#
# Epoch 00002: val_acc improved from 0.29539 to 0.32249, saving model to GRU_model.hdf5
# Epoch 3/150
# 2089/2089 [==============================] - 7s 3ms/step - loss: 1.7205 - acc: 0.2762 - val_loss: 1.3824 - val_acc: 0.3333
#
# Epoch 00003: val_acc improved from 0.32249 to 0.33333, saving model to GRU_model.hdf5
# Epoch 4/150
# 2089/2089 [==============================] - 7s 3ms/step - loss: 1.6414 - acc: 0.2781 - val_loss: 1.3385 - val_acc: 0.3740
#
# Epoch 00004: val_acc improved from 0.33333 to 0.37398, saving model to GRU_model.hdf5
# Epoch 5/150
# 2089/2089 [==============================] - 7s 3ms/step - loss: 1.6149 - acc: 0.2738 - val_loss: 1.3819 - val_acc: 0.3360
#
# Epoch 00005: val_acc did not improve
# Epoch 6/150
# 2089/2089 [==============================] - 7s 3ms/step - loss: 1.6146 - acc: 0.2867 - val_loss: 1.4419 - val_acc: 0.3279
#
# Epoch 00006: val_acc did not improve
# Epoch 7/150
# 2089/2089 [==============================] - 7s 3ms/step - loss: 1.5662 - acc: 0.2930 - val_loss: 1.4152 - val_acc: 0.3388
#
# Epoch 00007: val_acc did not improve
# Epoch 8/150
# 2089/2089 [==============================] - 6s 3ms/step - loss: 1.5437 - acc: 0.2997 - val_loss: 1.4328 - val_acc: 0.3550
#
# Epoch 00008: val_acc did not improve
# Epoch 9/150
# 2089/2089 [==============================] - 6s 3ms/step - loss: 1.5213 - acc: 0.3135 - val_loss: 1.4870 - val_acc: 0.3388
#
# Epoch 00009: val_acc did not improve
# Epoch 10/150
# 2089/2089 [==============================] - 6s 3ms/step - loss: 1.4905 - acc: 0.3193 - val_loss: 1.4830 - val_acc: 0.3225
#
# Epoch 00010: val_acc did not improve
# Epoch 11/150
# 2089/2089 [==============================] - 6s 3ms/step - loss: 1.4810 - acc: 0.2958 - val_loss: 1.4774 - val_acc: 0.3117
#
# Epoch 00011: val_acc did not improve
# Epoch 12/150
# 2089/2089 [==============================] - 7s 3ms/step - loss: 1.4530 - acc: 0.3073 - val_loss: 1.4538 - val_acc: 0.3469
#
# Epoch 00012: val_acc did not improve
# Epoch 13/150
# 2089/2089 [==============================] - 6s 3ms/step - loss: 1.4423 - acc: 0.3365 - val_loss: 1.4078 - val_acc: 0.3415
#
# Epoch 00013: val_acc did not improve
# Epoch 14/150
# 2089/2089 [==============================] - 6s 3ms/step - loss: 1.4439 - acc: 0.3351 - val_loss: 1.4117 - val_acc: 0.3631
#
# Epoch 00014: val_acc did not improve
# Epoch 15/150
# 2089/2089 [==============================] - 6s 3ms/step - loss: 1.4473 - acc: 0.3116 - val_loss: 1.3943 - val_acc: 0.3496
#
# Epoch 00015: val_acc did not improve
# Epoch 16/150
# 2089/2089 [==============================] - 6s 3ms/step - loss: 1.4139 - acc: 0.3337 - val_loss: 1.3829 - val_acc: 0.3713
#
# Epoch 00016: val_acc did not improve
# Epoch 17/150
# 2089/2089 [==============================] - 6s 3ms/step - loss: 1.3732 - acc: 0.3475 - val_loss: 1.3996 - val_acc: 0.3713
#
# Epoch 00017: val_acc did not improve
# Epoch 18/150
# 2089/2089 [==============================] - 6s 3ms/step - loss: 1.3804 - acc: 0.3514 - val_loss: 1.3844 - val_acc: 0.3794
#
# Epoch 00018: val_acc improved from 0.37398 to 0.37940, saving model to GRU_model.hdf5
# Epoch 19/150
# 2089/2089 [==============================] - 6s 3ms/step - loss: 1.3576 - acc: 0.3700 - val_loss: 1.3831 - val_acc: 0.3902
#
# Epoch 00019: val_acc improved from 0.37940 to 0.39024, saving model to GRU_model.hdf5
# Epoch 20/150
# 2089/2089 [==============================] - 6s 3ms/step - loss: 1.3686 - acc: 0.3485 - val_loss: 1.4140 - val_acc: 0.3604
#
# Epoch 00020: val_acc did not improve
# Epoch 21/150
# 2089/2089 [==============================] - 6s 3ms/step - loss: 1.3490 - acc: 0.3542 - val_loss: 1.4105 - val_acc: 0.3794
#
# Epoch 00021: val_acc did not improve
# Epoch 22/150
# 2089/2089 [==============================] - 6s 3ms/step - loss: 1.3249 - acc: 0.3782 - val_loss: 1.3895 - val_acc: 0.3875
#
# Epoch 00022: val_acc did not improve
# Epoch 23/150
# 2089/2089 [==============================] - 6s 3ms/step - loss: 1.3244 - acc: 0.3743 - val_loss: 1.3847 - val_acc: 0.3794
#
# Epoch 00023: val_acc did not improve
# Epoch 24/150
# 2089/2089 [==============================] - 6s 3ms/step - loss: 1.3204 - acc: 0.3810 - val_loss: 1.3863 - val_acc: 0.3821
#
# Epoch 00024: val_acc did not improve
# Epoch 25/150
# 2089/2089 [==============================] - 6s 3ms/step - loss: 1.3228 - acc: 0.3772 - val_loss: 1.3832 - val_acc: 0.3902
#
# Epoch 00025: val_acc did not improve
# Epoch 26/150
# 2089/2089 [==============================] - 6s 3ms/step - loss: 1.3098 - acc: 0.3944 - val_loss: 1.3824 - val_acc: 0.4038
#
# Epoch 00026: val_acc improved from 0.39024 to 0.40379, saving model to GRU_model.hdf5
# Epoch 27/150
# 2089/2089 [==============================] - 6s 3ms/step - loss: 1.2864 - acc: 0.4021 - val_loss: 1.3748 - val_acc: 0.3902
#
# Epoch 00027: val_acc did not improve
# Epoch 28/150
# 2089/2089 [==============================] - 6s 3ms/step - loss: 1.2846 - acc: 0.3959 - val_loss: 1.3977 - val_acc: 0.4038
#
# Epoch 00028: val_acc did not improve
# Epoch 29/150
# 2089/2089 [==============================] - 6s 3ms/step - loss: 1.2899 - acc: 0.4074 - val_loss: 1.3909 - val_acc: 0.4119
#
# Epoch 00029: val_acc improved from 0.40379 to 0.41192, saving model to GRU_model.hdf5
# Epoch 30/150
# 2089/2089 [==============================] - 6s 3ms/step - loss: 1.2854 - acc: 0.4122 - val_loss: 1.3937 - val_acc: 0.4038
#
# Epoch 00030: val_acc did not improve
# Epoch 31/150
# 2089/2089 [==============================] - 6s 3ms/step - loss: 1.2644 - acc: 0.4208 - val_loss: 1.3853 - val_acc: 0.3984
#
# Epoch 00031: val_acc did not improve
# Epoch 32/150
# 2089/2089 [==============================] - 7s 3ms/step - loss: 1.2648 - acc: 0.4131 - val_loss: 1.3728 - val_acc: 0.4146
#
# Epoch 00032: val_acc improved from 0.41192 to 0.41463, saving model to GRU_model.hdf5
# Epoch 33/150
# 2089/2089 [==============================] - 7s 3ms/step - loss: 1.2512 - acc: 0.4227 - val_loss: 1.3807 - val_acc: 0.4173
#
# Epoch 00033: val_acc improved from 0.41463 to 0.41734, saving model to GRU_model.hdf5
# Epoch 34/150
# 2089/2089 [==============================] - 7s 3ms/step - loss: 1.2629 - acc: 0.4055 - val_loss: 1.3749 - val_acc: 0.4065
#
# Epoch 00034: val_acc did not improve
# Epoch 35/150
# 2089/2089 [==============================] - 7s 3ms/step - loss: 1.2462 - acc: 0.4351 - val_loss: 1.3771 - val_acc: 0.3957
#
# Epoch 00035: val_acc did not improve
# Epoch 36/150
# 2089/2089 [==============================] - 6s 3ms/step - loss: 1.2439 - acc: 0.4246 - val_loss: 1.3698 - val_acc: 0.3957
#
# Epoch 00036: val_acc did not improve
# Epoch 37/150
# 2089/2089 [==============================] - 6s 3ms/step - loss: 1.2410 - acc: 0.4217 - val_loss: 1.3616 - val_acc: 0.3930
#
# Epoch 00037: val_acc did not improve
# Epoch 38/150
# 2089/2089 [==============================] - 6s 3ms/step - loss: 1.2287 - acc: 0.4385 - val_loss: 1.3557 - val_acc: 0.3984
#
# Epoch 00038: val_acc did not improve
# Epoch 39/150
# 2089/2089 [==============================] - 6s 3ms/step - loss: 1.2318 - acc: 0.4533 - val_loss: 1.3421 - val_acc: 0.3957
#
# Epoch 00039: val_acc did not improve
# Epoch 40/150
# 2089/2089 [==============================] - 6s 3ms/step - loss: 1.2379 - acc: 0.4275 - val_loss: 1.3424 - val_acc: 0.4038
#
# Epoch 00040: val_acc did not improve
# Epoch 41/150
# 2089/2089 [==============================] - 6s 3ms/step - loss: 1.2134 - acc: 0.4481 - val_loss: 1.3720 - val_acc: 0.4038
#
# Epoch 00041: val_acc did not improve
# Epoch 42/150
# 2089/2089 [==============================] - 6s 3ms/step - loss: 1.2207 - acc: 0.4576 - val_loss: 1.3646 - val_acc: 0.4065
#
# Epoch 00042: val_acc did not improve
# Epoch 43/150
# 2089/2089 [==============================] - 6s 3ms/step - loss: 1.2022 - acc: 0.4710 - val_loss: 1.3766 - val_acc: 0.3957
#
# Epoch 00043: val_acc did not improve
# Epoch 44/150
# 2089/2089 [==============================] - 6s 3ms/step - loss: 1.2234 - acc: 0.4519 - val_loss: 1.3405 - val_acc: 0.4146
#
# Epoch 00044: val_acc did not improve
# Epoch 45/150
# 2089/2089 [==============================] - 6s 3ms/step - loss: 1.1965 - acc: 0.4672 - val_loss: 1.3490 - val_acc: 0.3902
#
# Epoch 00045: val_acc did not improve
# Epoch 46/150
# 2089/2089 [==============================] - 6s 3ms/step - loss: 1.1834 - acc: 0.4806 - val_loss: 1.3399 - val_acc: 0.4065
#
# Epoch 00046: val_acc did not improve
# Epoch 47/150
# 2089/2089 [==============================] - 6s 3ms/step - loss: 1.1837 - acc: 0.4763 - val_loss: 1.3212 - val_acc: 0.4119
#
# Epoch 00047: val_acc did not improve
# Epoch 48/150
# 2089/2089 [==============================] - 6s 3ms/step - loss: 1.1628 - acc: 0.4921 - val_loss: 1.3453 - val_acc: 0.3848
#
# Epoch 00048: val_acc did not improve
# Epoch 49/150
# 2089/2089 [==============================] - 6s 3ms/step - loss: 1.1789 - acc: 0.4816 - val_loss: 1.3428 - val_acc: 0.3957
#
# Epoch 00049: val_acc did not improve
# Epoch 50/150
# 2089/2089 [==============================] - 6s 3ms/step - loss: 1.1775 - acc: 0.4797 - val_loss: 1.3603 - val_acc: 0.3875
#
# Epoch 00050: val_acc did not improve
# Epoch 51/150
# 2089/2089 [==============================] - 6s 3ms/step - loss: 1.1729 - acc: 0.4792 - val_loss: 1.3395 - val_acc: 0.3930
#
# Epoch 00051: val_acc did not improve
# Epoch 52/150
# 2089/2089 [==============================] - 7s 3ms/step - loss: 1.1599 - acc: 0.4820 - val_loss: 1.3421 - val_acc: 0.4011
#
# Epoch 00052: val_acc did not improve
# Epoch 53/150
# 2089/2089 [==============================] - 7s 3ms/step - loss: 1.1589 - acc: 0.4854 - val_loss: 1.3474 - val_acc: 0.4065
#
# Epoch 00053: val_acc did not improve
# Epoch 54/150
# 2089/2089 [==============================] - 6s 3ms/step - loss: 1.1578 - acc: 0.4801 - val_loss: 1.3524 - val_acc: 0.4011
#
# Epoch 00054: val_acc did not improve
# Epoch 55/150
# 2089/2089 [==============================] - 6s 3ms/step - loss: 1.1509 - acc: 0.5055 - val_loss: 1.3524 - val_acc: 0.4011
#
# Epoch 00055: val_acc did not improve
# Epoch 56/150
# 2089/2089 [==============================] - 6s 3ms/step - loss: 1.1334 - acc: 0.5136 - val_loss: 1.3637 - val_acc: 0.4038
#
# Epoch 00056: val_acc did not improve
# Epoch 57/150
# 2089/2089 [==============================] - 6s 3ms/step - loss: 1.1133 - acc: 0.5084 - val_loss: 1.3721 - val_acc: 0.3930
#
# Epoch 00057: val_acc did not improve
# Epoch 58/150
# 2089/2089 [==============================] - 6s 3ms/step - loss: 1.1195 - acc: 0.5127 - val_loss: 1.3507 - val_acc: 0.3984
#
# Epoch 00058: val_acc did not improve
# Epoch 59/150
# 2089/2089 [==============================] - 6s 3ms/step - loss: 1.0971 - acc: 0.5390 - val_loss: 1.3483 - val_acc: 0.4011
#
# Epoch 00059: val_acc did not improve
# Epoch 60/150
# 2089/2089 [==============================] - 6s 3ms/step - loss: 1.0921 - acc: 0.5371 - val_loss: 1.3391 - val_acc: 0.3957
#
# Epoch 00060: val_acc did not improve
# Epoch 61/150
# 2089/2089 [==============================] - 6s 3ms/step - loss: 1.0866 - acc: 0.5543 - val_loss: 1.3488 - val_acc: 0.4092
#
# Epoch 00061: val_acc did not improve
# Epoch 62/150
# 2089/2089 [==============================] - 6s 3ms/step - loss: 1.0942 - acc: 0.5390 - val_loss: 1.3526 - val_acc: 0.3902
#
# Epoch 00062: val_acc did not improve
# Epoch 63/150
# 2089/2089 [==============================] - 6s 3ms/step - loss: 1.0850 - acc: 0.5467 - val_loss: 1.3475 - val_acc: 0.3821
#
# Epoch 00063: val_acc did not improve
# Epoch 64/150
# 2089/2089 [==============================] - 6s 3ms/step - loss: 1.0773 - acc: 0.5400 - val_loss: 1.3515 - val_acc: 0.3848
#
# Epoch 00064: val_acc did not improve
# Epoch 65/150
# 2089/2089 [==============================] - 6s 3ms/step - loss: 1.0624 - acc: 0.5524 - val_loss: 1.3533 - val_acc: 0.3984
#
# Epoch 00065: val_acc did not improve
# Epoch 66/150
# 2089/2089 [==============================] - 6s 3ms/step - loss: 1.0629 - acc: 0.5299 - val_loss: 1.3407 - val_acc: 0.4038
#
# Epoch 00066: val_acc did not improve
# Epoch 67/150
# 2089/2089 [==============================] - 6s 3ms/step - loss: 1.0445 - acc: 0.5620 - val_loss: 1.3302 - val_acc: 0.4038
#
# Epoch 00067: val_acc did not improve
# Epoch 68/150
# 2089/2089 [==============================] - 6s 3ms/step - loss: 1.0439 - acc: 0.5472 - val_loss: 1.3371 - val_acc: 0.3957
#
# Epoch 00068: val_acc did not improve
# Epoch 69/150
# 2089/2089 [==============================] - 6s 3ms/step - loss: 1.0340 - acc: 0.5716 - val_loss: 1.3321 - val_acc: 0.4119
#
# Epoch 00069: val_acc did not improve
# Epoch 70/150
# 2089/2089 [==============================] - 6s 3ms/step - loss: 1.0523 - acc: 0.5472 - val_loss: 1.3374 - val_acc: 0.4146
#
# Epoch 00070: val_acc did not improve
# Epoch 71/150
# 2089/2089 [==============================] - 6s 3ms/step - loss: 1.0160 - acc: 0.5797 - val_loss: 1.3505 - val_acc: 0.4119
#
# Epoch 00071: val_acc did not improve
# Epoch 72/150
# 2089/2089 [==============================] - 6s 3ms/step - loss: 1.0168 - acc: 0.5634 - val_loss: 1.3394 - val_acc: 0.4038
#
# Epoch 00072: val_acc did not improve
# Epoch 73/150
# 2089/2089 [==============================] - 7s 3ms/step - loss: 1.0078 - acc: 0.5816 - val_loss: 1.3319 - val_acc: 0.4065
#
# Epoch 00073: val_acc did not improve
# Epoch 74/150
# 2089/2089 [==============================] - 6s 3ms/step - loss: 0.9999 - acc: 0.5854 - val_loss: 1.3316 - val_acc: 0.3902
#
# Epoch 00074: val_acc did not improve
# Epoch 75/150
# 2089/2089 [==============================] - 6s 3ms/step - loss: 1.0004 - acc: 0.5826 - val_loss: 1.3442 - val_acc: 0.4065
#
# Epoch 00075: val_acc did not improve
# Epoch 76/150
# 2089/2089 [==============================] - 6s 3ms/step - loss: 0.9838 - acc: 0.5979 - val_loss: 1.3521 - val_acc: 0.4065
#
# Epoch 00076: val_acc did not improve
# Epoch 77/150
# 2089/2089 [==============================] - 6s 3ms/step - loss: 0.9690 - acc: 0.6032 - val_loss: 1.3636 - val_acc: 0.3821
#
# Epoch 00077: val_acc did not improve
# Epoch 78/150
# 2089/2089 [==============================] - 6s 3ms/step - loss: 0.9474 - acc: 0.6175 - val_loss: 1.3462 - val_acc: 0.4038
#
# Epoch 00078: val_acc did not improve
# Epoch 79/150
# 2089/2089 [==============================] - 6s 3ms/step - loss: 0.9775 - acc: 0.6027 - val_loss: 1.3654 - val_acc: 0.4011
#
# Epoch 00079: val_acc did not improve
# Epoch 80/150
# 2089/2089 [==============================] - 6s 3ms/step - loss: 0.9457 - acc: 0.6228 - val_loss: 1.3776 - val_acc: 0.3821
#
# Epoch 00080: val_acc did not improve
# Epoch 81/150
# 2089/2089 [==============================] - 6s 3ms/step - loss: 0.9308 - acc: 0.6290 - val_loss: 1.3733 - val_acc: 0.3794
#
# Epoch 00081: val_acc did not improve
# Epoch 82/150
# 2089/2089 [==============================] - 6s 3ms/step - loss: 0.9378 - acc: 0.6089 - val_loss: 1.3634 - val_acc: 0.3767
#
# Epoch 00082: val_acc did not improve
# Epoch 83/150
# 2089/2089 [==============================] - 6s 3ms/step - loss: 0.9201 - acc: 0.6348 - val_loss: 1.3800 - val_acc: 0.3875
#
# Epoch 00083: val_acc did not improve
# Epoch 84/150
# 2089/2089 [==============================] - 6s 3ms/step - loss: 0.9038 - acc: 0.6319 - val_loss: 1.3703 - val_acc: 0.4011
#
# Epoch 00084: val_acc did not improve
# Epoch 85/150
# 2089/2089 [==============================] - 6s 3ms/step - loss: 0.8726 - acc: 0.6424 - val_loss: 1.3761 - val_acc: 0.4065
#
# Epoch 00085: val_acc did not improve
# Epoch 86/150
# 2089/2089 [==============================] - 6s 3ms/step - loss: 0.8806 - acc: 0.6386 - val_loss: 1.3826 - val_acc: 0.4065
#
# Epoch 00086: val_acc did not improve
# Epoch 87/150
# 2089/2089 [==============================] - 6s 3ms/step - loss: 0.8601 - acc: 0.6587 - val_loss: 1.3808 - val_acc: 0.3984
#
# Epoch 00087: val_acc did not improve
# Epoch 88/150
# 2089/2089 [==============================] - 6s 3ms/step - loss: 0.8915 - acc: 0.6391 - val_loss: 1.3850 - val_acc: 0.3930
#
# Epoch 00088: val_acc did not improve
# Epoch 89/150
# 2089/2089 [==============================] - 6s 3ms/step - loss: 0.8570 - acc: 0.6424 - val_loss: 1.3837 - val_acc: 0.3930
#
# Epoch 00089: val_acc did not improve
# Epoch 90/150
# 2089/2089 [==============================] - 6s 3ms/step - loss: 0.8205 - acc: 0.6764 - val_loss: 1.3963 - val_acc: 0.3930
#
# Epoch 00090: val_acc did not improve
# Epoch 91/150
# 2089/2089 [==============================] - 6s 3ms/step - loss: 0.8318 - acc: 0.6711 - val_loss: 1.4043 - val_acc: 0.4146
#
# Epoch 00091: val_acc did not improve
# Epoch 92/150
# 2089/2089 [==============================] - 6s 3ms/step - loss: 0.8130 - acc: 0.6879 - val_loss: 1.4054 - val_acc: 0.4092
#
# Epoch 00092: val_acc did not improve
# Epoch 93/150
# 2089/2089 [==============================] - 7s 3ms/step - loss: 0.7918 - acc: 0.6745 - val_loss: 1.4024 - val_acc: 0.3957
#
# Epoch 00093: val_acc did not improve
# Epoch 94/150
# 2089/2089 [==============================] - 7s 3ms/step - loss: 0.8075 - acc: 0.6850 - val_loss: 1.4055 - val_acc: 0.3984
#
# Epoch 00094: val_acc did not improve
# Epoch 95/150
# 2089/2089 [==============================] - 6s 3ms/step - loss: 0.7742 - acc: 0.6888 - val_loss: 1.4238 - val_acc: 0.3930
#
# Epoch 00095: val_acc did not improve
# Epoch 96/150
# 2089/2089 [==============================] - 6s 3ms/step - loss: 0.7688 - acc: 0.6898 - val_loss: 1.4378 - val_acc: 0.4038
#
# Epoch 00096: val_acc did not improve
# Epoch 97/150
# 2089/2089 [==============================] - 6s 3ms/step - loss: 0.7516 - acc: 0.7051 - val_loss: 1.4440 - val_acc: 0.4146
#
# Epoch 00097: val_acc did not improve
# Epoch 98/150
# 2089/2089 [==============================] - 6s 3ms/step - loss: 0.7678 - acc: 0.6970 - val_loss: 1.4718 - val_acc: 0.4038
#
# Epoch 00098: val_acc did not improve
# Epoch 99/150
# 2089/2089 [==============================] - 6s 3ms/step - loss: 0.7445 - acc: 0.7094 - val_loss: 1.4641 - val_acc: 0.4011
#
# Epoch 00099: val_acc did not improve
# Epoch 100/150
# 2089/2089 [==============================] - 6s 3ms/step - loss: 0.7414 - acc: 0.7080 - val_loss: 1.4690 - val_acc: 0.3930
#
# Epoch 00100: val_acc did not improve
# Epoch 101/150
# 2089/2089 [==============================] - 6s 3ms/step - loss: 0.7290 - acc: 0.7046 - val_loss: 1.4820 - val_acc: 0.4011
#
# Epoch 00101: val_acc did not improve
# Epoch 102/150
# 2089/2089 [==============================] - 6s 3ms/step - loss: 0.6842 - acc: 0.7391 - val_loss: 1.4781 - val_acc: 0.3875
#
# Epoch 00102: val_acc did not improve
# Epoch 103/150
# 2089/2089 [==============================] - 6s 3ms/step - loss: 0.6946 - acc: 0.7243 - val_loss: 1.4902 - val_acc: 0.3875
#
# Epoch 00103: val_acc did not improve
# Epoch 104/150
# 2089/2089 [==============================] - 6s 3ms/step - loss: 0.6953 - acc: 0.7233 - val_loss: 1.4945 - val_acc: 0.3930
#
# Epoch 00104: val_acc did not improve
# Epoch 105/150
# 2089/2089 [==============================] - 6s 3ms/step - loss: 0.6876 - acc: 0.7324 - val_loss: 1.4854 - val_acc: 0.3930
#
# Epoch 00105: val_acc did not improve
# Epoch 106/150
# 2089/2089 [==============================] - 6s 3ms/step - loss: 0.6711 - acc: 0.7487 - val_loss: 1.5120 - val_acc: 0.3875
#
# Epoch 00106: val_acc did not improve
# Epoch 107/150
# 2089/2089 [==============================] - 6s 3ms/step - loss: 0.6538 - acc: 0.7578 - val_loss: 1.5123 - val_acc: 0.3848
#
# Epoch 00107: val_acc did not improve
# Epoch 108/150
# 2089/2089 [==============================] - 6s 3ms/step - loss: 0.6483 - acc: 0.7506 - val_loss: 1.5160 - val_acc: 0.3821
#
# Epoch 00108: val_acc did not improve
# Epoch 109/150
# 2089/2089 [==============================] - 6s 3ms/step - loss: 0.6342 - acc: 0.7559 - val_loss: 1.5278 - val_acc: 0.3930
#
# Epoch 00109: val_acc did not improve
# Epoch 110/150
# 2089/2089 [==============================] - 6s 3ms/step - loss: 0.6222 - acc: 0.7506 - val_loss: 1.5191 - val_acc: 0.3848
#
# Epoch 00110: val_acc did not improve
# Epoch 111/150
# 2089/2089 [==============================] - 6s 3ms/step - loss: 0.6076 - acc: 0.7697 - val_loss: 1.5283 - val_acc: 0.3930
#
# Epoch 00111: val_acc did not improve
# Epoch 112/150
# 2089/2089 [==============================] - 6s 3ms/step - loss: 0.5964 - acc: 0.7731 - val_loss: 1.5519 - val_acc: 0.4065
#
# Epoch 00112: val_acc did not improve
# Epoch 113/150
# 2089/2089 [==============================] - 6s 3ms/step - loss: 0.5870 - acc: 0.7803 - val_loss: 1.5489 - val_acc: 0.4038
#
# Epoch 00113: val_acc did not improve
# Epoch 114/150
# 2089/2089 [==============================] - 7s 3ms/step - loss: 0.5689 - acc: 0.7879 - val_loss: 1.5389 - val_acc: 0.4146
#
# Epoch 00114: val_acc did not improve
# Epoch 115/150
# 2089/2089 [==============================] - 6s 3ms/step - loss: 0.5491 - acc: 0.7999 - val_loss: 1.5519 - val_acc: 0.3902
#
# Epoch 00115: val_acc did not improve
# Epoch 116/150
# 2089/2089 [==============================] - 6s 3ms/step - loss: 0.5703 - acc: 0.7975 - val_loss: 1.5747 - val_acc: 0.3984
#
# Epoch 00116: val_acc did not improve
# Epoch 117/150
# 2089/2089 [==============================] - 6s 3ms/step - loss: 0.5422 - acc: 0.7994 - val_loss: 1.6364 - val_acc: 0.3848
#
# Epoch 00117: val_acc did not improve

# %%
# list all data in history
print(history.history.keys())

# summarize history for accuracy
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# summarize history for loss
plt.plot(history.history['loss'],'o')
plt.plot(history.history['val_loss'],'o')
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()
# Out:
# dict_keys(['val_loss', 'val_acc', 'loss', 'acc'])

# %%
# evaluate model on entire training set
model = load_model('GRU_model.hdf5')
model.evaluate(X_train_sub,y_train,batch_size=N_train)
# Out:
# 2458/2458 [==============================] - 3s 1ms/step
# [1.1615756750106812, 0.48779496550559998]

# %%
# evaluate model on test set
model.evaluate(X_test_sub,y_test,batch_size=N_test)
# Out:
# 100/100 [==============================] - 0s 1ms/step
# [1.2827786207199097, 0.43999999761581421]
