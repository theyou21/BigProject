# %%
from keras.models import Sequential
from keras.layers import LSTM, GRU, Dense, Dropout, TimeDistributed, BatchNormalization, Flatten, Activation
from keras import regularizers
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.models import load_model
import numpy as np
import h5py
import matplotlib.pyplot as plt
from data_utils import get_data
from sklearn import preprocessing
from functools import reduce
from scipy.fftpack import dct, idct
from scipy import signal

# %%
# Load data from all .mat files, combine them, eliminate EOG signals, shuffle and 
# seperate training data, validation data and testing data.
# Also do mean subtraction on x.

data = get_data('project_datasets',num_validation=0, num_test=100, subtract_mean=False, subtract_axis=1,
                transpose=True)
for k in data.keys():
    print('{}: {} '.format(k, data[k].shape))
# Out:
# X_train: (2458, 1000, 22)
# y_train: (2458,)
# X_val: (0, 1000, 22)
# y_val: (0,)
# X_test: (100, 1000, 22)
# y_test: (100,)

# %%
# substract data from list
X_train = data.get('X_train')
y_train = data.get('y_train')
#X_val = data.get('X_val')
#y_val = data.get('y_val')
X_test = data.get('X_test')
y_test = data.get('y_test')

# get data dimension
N_train, T_train, C_train = data.get('X_train').shape
N_val, T_val, C_val = data.get('X_val').shape
N_test, T_test, C_test = data.get('X_test').shape

# add dummy zeros for y classification
lb = preprocessing.LabelBinarizer()
lb.fit([0, 1, 2, 3,])
lb.classes_
y_train = lb.transform(y_train)
if (N_val > 0): y_val = lb.transform(y_val)
y_test = lb.transform(y_test)

# %%
# Filtering through FFT(discrete cosine transform)

def filter(x, low=0, high=1, plot=False):
    N = x.shape[0]
    t = np.linspace(0,N,N)
    y = dct(x, norm='ortho')
    window = np.zeros(N)
    window[int(low*N):int(high*N)] = 1
    yr = idct(y*window, norm='ortho')
    sum(abs(x-yr)**2) / sum(abs(x)**2)
    if plot:
        plt.plot(t, x, '-b')
        plt.plot(t, yr, 'r')
    return x

# Filter band
low_freq = 0.02
high_freq = 0.4

for i in np.arange(N_train):
    for j in np.arange(C_train):
       X_train[i,:,j]= filter(X_train[i,:,j],low_freq,high_freq)
for i in np.arange(N_val):
    for j in arange(C_val):
       X_val[i,:,j]= filter(X_val[i,:,j],low_freq,high_freq)
    
for i in np.arange(N_test):
    for j in np.arange(C_test):
       X_test[i,:,j]= filter(X_test[i,:,j],low_freq,high_freq)

# %%
# Downsampling in time through FFT

t_sample = 100
X_train_sub = signal.resample(X_train,t_sample,axis=1)
if (N_val > 0): X_val_sub = signal.resample(X_val,t_sample,axis=1)
X_test_sub = signal.resample(X_test,t_sample,axis=1)

# show a downsampling example
plt.plot(np.linspace(0,1,T_train),X_train[5,:,5],'-b')
plt.plot(np.linspace(0,1,t_sample),X_train_sub[5,:,5],'-r')

# %%
print(X_train_sub.shape)
# Out:
# (2458, 100, 22)

# %%
# # normalize data across the time sequence dimension only
# scaler = preprocessing.MinMaxScaler()
# for i in range(N_train):
#     scaler.fit(X_train[i,:,:])
#     X_train[i,:,:] = scaler.transform(X_train[i,:,:])
    
# for i in range(N_val):
#     scaler.fit(X_val[i,:,:])
#     X_val[i,:,:] = scaler.transform(X_val[i,:,:])

# %%
# def downsample(data, mul=10, enableTrunc = False):
#     assert data.shape[0] % mul == 0 or  enableTrunc, "Can't downsample without data truncation.\
#                                                 \n Set another value of mul or set enableTrunc = True"
#     outdata = []
#     for i in range(data.shape[0]//mul):
#         outdata.append(np.mean(data[i*mul:(i+1)*mul,...], axis=0, keepdims=True))
#     outdata = reduce(lambda a,b: np.append(a,b,0), outdata)
    
#     return outdata
# span = 2
# X_train_sub = np.expand_dims(downsample(X_train[0,:,:], mul=span),axis=0)
# for n in np.arange(1,X_train.shape[0]):
#     X_train_sub = np.append(X_train_sub,
#                             np.expand_dims(downsample(X_train[n,:,:], mul=span),axis=0),axis=0)

# X_val_sub = np.expand_dims(downsample(X_val[0,:,:], mul=span),axis=0)
# for n in np.arange(1,X_val.shape[0]):
#     X_val_sub = np.append(X_val_sub,
#                             np.expand_dims(downsample(X_val[n,:,:], mul=span),axis=0),axis=0)

# print('X_train_sub: ', X_train_sub.shape)
# print('X_val_sub: ', X_val_sub.shape)

# %%
# Expected input shape: ([batch_size], timesteps, data_dim)
# Note that we have to provide the full batch_input_shape if the network is stateful.
# the sample of index i in batch k is the follow-up for the sample i in batch k-1.

# perhaps should try masking layer

data_dim = C_train
seq_split = 1 # Set to one when using FFT to down sample
seq_len = int(X_train_sub.shape[1]*seq_split)
timesteps = seq_len
num_classes = 4
batch_size = 200
num_epoch = 100

model = Sequential()
#1
model.add(GRU(200, return_sequences=True, stateful=False,
          recurrent_dropout=0.6, dropout = 0.6, input_shape=(timesteps, data_dim)))

#2
model.add(GRU(100, return_sequences=True, stateful=False,
          recurrent_dropout=0.6, dropout = 0.6))

#3
model.add(GRU(50, return_sequences=True, stateful=False,
          recurrent_dropout=0.6, dropout = 0.6))
model.add(Flatten())

#4
model.add(Dense(100))
model.add(BatchNormalization(axis=-1))
model.add(Activation('relu'))
model.add(Dropout(0.5))

#5
model.add(Dense(num_classes, activation='softmax'))

model.compile(loss='categorical_crossentropy',
              optimizer='rmsprop',
              metrics=['accuracy'])

# define early stopping callback
earlystop = EarlyStopping(monitor='val_loss', min_delta=0.001, patience=30, mode='auto')

# saves the model weights after each epoch if the validation loss decreased
checkpointer = ModelCheckpoint(filepath='GRU_model.hdf5', monitor='val_acc', verbose=1, save_best_only=True)

callbacks_list = [earlystop, checkpointer]

# %%
history = model.fit(X_train_sub[:,:seq_len,:], y_train,
                    batch_size=batch_size, epochs=num_epoch, shuffle=True,
                    validation_split = 0.15, callbacks=callbacks_list)
# Out:
# Train on 2089 samples, validate on 369 samples
# Epoch 1/100
# 2089/2089 [==============================] - 13s 6ms/step - loss: 1.8879 - acc: 0.2671 - val_loss: 1.4175 - val_acc: 0.3035
#
# Epoch 00001: val_acc improved from -inf to 0.30352, saving model to GRU_model.hdf5
# Epoch 2/100
# 2089/2089 [==============================] - 14s 7ms/step - loss: 1.7654 - acc: 0.2628 - val_loss: 1.3912 - val_acc: 0.2846
#
# Epoch 00002: val_acc did not improve
# Epoch 3/100
# 2089/2089 [==============================] - 14s 7ms/step - loss: 1.6431 - acc: 0.2867 - val_loss: 1.4343 - val_acc: 0.2900
#
# Epoch 00003: val_acc did not improve
# Epoch 4/100
# 2089/2089 [==============================] - 13s 6ms/step - loss: 1.6432 - acc: 0.2757 - val_loss: 1.3818 - val_acc: 0.3388
#
# Epoch 00004: val_acc improved from 0.30352 to 0.33875, saving model to GRU_model.hdf5
# Epoch 5/100
# 2089/2089 [==============================] - 13s 6ms/step - loss: 1.5831 - acc: 0.2973 - val_loss: 1.3942 - val_acc: 0.3550
#
# Epoch 00005: val_acc improved from 0.33875 to 0.35501, saving model to GRU_model.hdf5
# Epoch 6/100
# 2089/2089 [==============================] - 14s 7ms/step - loss: 1.5568 - acc: 0.2930 - val_loss: 1.4375 - val_acc: 0.3062
#
# Epoch 00006: val_acc did not improve
# Epoch 7/100
# 2089/2089 [==============================] - 13s 6ms/step - loss: 1.5528 - acc: 0.2896 - val_loss: 1.4328 - val_acc: 0.3279
#
# Epoch 00007: val_acc did not improve
# Epoch 8/100
# 2089/2089 [==============================] - 13s 6ms/step - loss: 1.4911 - acc: 0.3164 - val_loss: 1.4749 - val_acc: 0.2900
#
# Epoch 00008: val_acc did not improve
# Epoch 9/100
# 2089/2089 [==============================] - 13s 6ms/step - loss: 1.4841 - acc: 0.3049 - val_loss: 1.4969 - val_acc: 0.3252
#
# Epoch 00009: val_acc did not improve
# Epoch 10/100
# 2089/2089 [==============================] - 13s 6ms/step - loss: 1.4768 - acc: 0.3083 - val_loss: 1.4797 - val_acc: 0.3306
#
# Epoch 00010: val_acc did not improve
# Epoch 11/100
# 2089/2089 [==============================] - 13s 6ms/step - loss: 1.4594 - acc: 0.3183 - val_loss: 1.4209 - val_acc: 0.3252
#
# Epoch 00011: val_acc did not improve
# Epoch 12/100
# 2089/2089 [==============================] - 13s 6ms/step - loss: 1.4304 - acc: 0.3274 - val_loss: 1.4680 - val_acc: 0.3171
#
# Epoch 00012: val_acc did not improve
# Epoch 13/100
# 2089/2089 [==============================] - 13s 6ms/step - loss: 1.4208 - acc: 0.3399 - val_loss: 1.3770 - val_acc: 0.3794
#
# Epoch 00013: val_acc improved from 0.35501 to 0.37940, saving model to GRU_model.hdf5
# Epoch 14/100
# 2089/2089 [==============================] - 15s 7ms/step - loss: 1.4012 - acc: 0.3337 - val_loss: 1.4073 - val_acc: 0.3740
#
# Epoch 00014: val_acc did not improve
# Epoch 15/100
# 2089/2089 [==============================] - 15s 7ms/step - loss: 1.4078 - acc: 0.3365 - val_loss: 1.3799 - val_acc: 0.3713
#
# Epoch 00015: val_acc did not improve
# Epoch 16/100
# 2089/2089 [==============================] - 13s 6ms/step - loss: 1.3887 - acc: 0.3576 - val_loss: 1.3827 - val_acc: 0.3604
#
# Epoch 00016: val_acc did not improve
# Epoch 17/100
# 2089/2089 [==============================] - 13s 6ms/step - loss: 1.3617 - acc: 0.3557 - val_loss: 1.3840 - val_acc: 0.3388
#
# Epoch 00017: val_acc did not improve
# Epoch 18/100
# 2089/2089 [==============================] - 13s 6ms/step - loss: 1.3595 - acc: 0.3734 - val_loss: 1.4016 - val_acc: 0.3279
#
# Epoch 00018: val_acc did not improve
# Epoch 19/100
# 2089/2089 [==============================] - 13s 6ms/step - loss: 1.3601 - acc: 0.3447 - val_loss: 1.4026 - val_acc: 0.3469
#
# Epoch 00019: val_acc did not improve
# Epoch 20/100
# 2089/2089 [==============================] - 13s 6ms/step - loss: 1.3604 - acc: 0.3600 - val_loss: 1.3754 - val_acc: 0.3388
#
# Epoch 00020: val_acc did not improve
# Epoch 21/100
# 2089/2089 [==============================] - 13s 6ms/step - loss: 1.3523 - acc: 0.3518 - val_loss: 1.3761 - val_acc: 0.3604
#
# Epoch 00021: val_acc did not improve
# Epoch 22/100
# 2089/2089 [==============================] - 13s 6ms/step - loss: 1.3232 - acc: 0.3753 - val_loss: 1.3961 - val_acc: 0.3496
#
# Epoch 00022: val_acc did not improve
# Epoch 23/100
# 2089/2089 [==============================] - 14s 7ms/step - loss: 1.3341 - acc: 0.3748 - val_loss: 1.3885 - val_acc: 0.3659
#
# Epoch 00023: val_acc did not improve
# Epoch 24/100
# 2089/2089 [==============================] - 14s 7ms/step - loss: 1.3097 - acc: 0.3863 - val_loss: 1.3952 - val_acc: 0.3686
#
# Epoch 00024: val_acc did not improve
# Epoch 25/100
# 2089/2089 [==============================] - 13s 6ms/step - loss: 1.3136 - acc: 0.3763 - val_loss: 1.3805 - val_acc: 0.3604
#
# Epoch 00025: val_acc did not improve
# Epoch 26/100
# 2089/2089 [==============================] - 15s 7ms/step - loss: 1.3049 - acc: 0.3882 - val_loss: 1.3799 - val_acc: 0.3875
#
# Epoch 00026: val_acc improved from 0.37940 to 0.38753, saving model to GRU_model.hdf5
# Epoch 27/100
# 2089/2089 [==============================] - 13s 6ms/step - loss: 1.2871 - acc: 0.4064 - val_loss: 1.3503 - val_acc: 0.4038
#
# Epoch 00027: val_acc improved from 0.38753 to 0.40379, saving model to GRU_model.hdf5
# Epoch 28/100
# 2089/2089 [==============================] - 13s 6ms/step - loss: 1.2795 - acc: 0.4031 - val_loss: 1.3890 - val_acc: 0.3902
#
# Epoch 00028: val_acc did not improve
# Epoch 29/100
# 2089/2089 [==============================] - 14s 7ms/step - loss: 1.2834 - acc: 0.4069 - val_loss: 1.3574 - val_acc: 0.4119
#
# Epoch 00029: val_acc improved from 0.40379 to 0.41192, saving model to GRU_model.hdf5
# Epoch 30/100
# 2089/2089 [==============================] - 14s 7ms/step - loss: 1.2683 - acc: 0.4193 - val_loss: 1.3515 - val_acc: 0.4038
#
# Epoch 00030: val_acc did not improve
# Epoch 31/100
# 2089/2089 [==============================] - 14s 6ms/step - loss: 1.2520 - acc: 0.4284 - val_loss: 1.3690 - val_acc: 0.3902
#
# Epoch 00031: val_acc did not improve
# Epoch 32/100
# 2089/2089 [==============================] - 15s 7ms/step - loss: 1.2555 - acc: 0.4174 - val_loss: 1.3457 - val_acc: 0.4092
#
# Epoch 00032: val_acc did not improve
# Epoch 33/100
# 2089/2089 [==============================] - 13s 6ms/step - loss: 1.2589 - acc: 0.4246 - val_loss: 1.3445 - val_acc: 0.4228
#
# Epoch 00033: val_acc improved from 0.41192 to 0.42276, saving model to GRU_model.hdf5
# Epoch 34/100
# 2089/2089 [==============================] - 13s 6ms/step - loss: 1.2388 - acc: 0.4409 - val_loss: 1.3508 - val_acc: 0.3957
#
# Epoch 00034: val_acc did not improve
# Epoch 35/100
# 2089/2089 [==============================] - 13s 6ms/step - loss: 1.2388 - acc: 0.4461 - val_loss: 1.3357 - val_acc: 0.4201
#
# Epoch 00035: val_acc did not improve
# Epoch 36/100
# 2089/2089 [==============================] - 12s 6ms/step - loss: 1.2540 - acc: 0.4356 - val_loss: 1.3301 - val_acc: 0.4255
#
# Epoch 00036: val_acc improved from 0.42276 to 0.42547, saving model to GRU_model.hdf5
# Epoch 37/100
# 2089/2089 [==============================] - 13s 6ms/step - loss: 1.2287 - acc: 0.4466 - val_loss: 1.3333 - val_acc: 0.4065
#
# Epoch 00037: val_acc did not improve
# Epoch 38/100
# 2089/2089 [==============================] - 15s 7ms/step - loss: 1.2295 - acc: 0.4390 - val_loss: 1.3360 - val_acc: 0.4282
#
# Epoch 00038: val_acc improved from 0.42547 to 0.42818, saving model to GRU_model.hdf5
# Epoch 39/100
# 2089/2089 [==============================] - 13s 6ms/step - loss: 1.2143 - acc: 0.4600 - val_loss: 1.3375 - val_acc: 0.4119
#
# Epoch 00039: val_acc did not improve
# Epoch 40/100
# 2089/2089 [==============================] - 13s 6ms/step - loss: 1.2234 - acc: 0.4509 - val_loss: 1.3263 - val_acc: 0.4173
#
# Epoch 00040: val_acc did not improve
# Epoch 41/100
# 2089/2089 [==============================] - 14s 7ms/step - loss: 1.2318 - acc: 0.4423 - val_loss: 1.3450 - val_acc: 0.4092
#
# Epoch 00041: val_acc did not improve
# Epoch 42/100
# 2089/2089 [==============================] - 13s 6ms/step - loss: 1.2157 - acc: 0.4619 - val_loss: 1.3529 - val_acc: 0.3902
#
# Epoch 00042: val_acc did not improve
# Epoch 43/100
# 2089/2089 [==============================] - 14s 7ms/step - loss: 1.1990 - acc: 0.4715 - val_loss: 1.3297 - val_acc: 0.4011
#
# Epoch 00043: val_acc did not improve
# Epoch 44/100
# 2089/2089 [==============================] - 13s 6ms/step - loss: 1.2075 - acc: 0.4648 - val_loss: 1.3363 - val_acc: 0.4038
#
# Epoch 00044: val_acc did not improve
# Epoch 45/100
# 2089/2089 [==============================] - 13s 6ms/step - loss: 1.1893 - acc: 0.4600 - val_loss: 1.3216 - val_acc: 0.4173
#
# Epoch 00045: val_acc did not improve
# Epoch 46/100
# 2089/2089 [==============================] - 13s 6ms/step - loss: 1.1789 - acc: 0.4897 - val_loss: 1.3059 - val_acc: 0.4146
#
# Epoch 00046: val_acc did not improve
# Epoch 47/100
# 2089/2089 [==============================] - 13s 6ms/step - loss: 1.1891 - acc: 0.4777 - val_loss: 1.3177 - val_acc: 0.4011
#
# Epoch 00047: val_acc did not improve
# Epoch 48/100
# 2089/2089 [==============================] - 13s 6ms/step - loss: 1.1739 - acc: 0.4844 - val_loss: 1.3154 - val_acc: 0.4011
#
# Epoch 00048: val_acc did not improve
# Epoch 49/100
# 2089/2089 [==============================] - 13s 6ms/step - loss: 1.1670 - acc: 0.4883 - val_loss: 1.3122 - val_acc: 0.4011
#
# Epoch 00049: val_acc did not improve
# Epoch 50/100
# 2089/2089 [==============================] - 15s 7ms/step - loss: 1.1706 - acc: 0.4945 - val_loss: 1.3226 - val_acc: 0.4038
#
# Epoch 00050: val_acc did not improve
# Epoch 51/100
# 2089/2089 [==============================] - 14s 7ms/step - loss: 1.1537 - acc: 0.4935 - val_loss: 1.3260 - val_acc: 0.4065
#
# Epoch 00051: val_acc did not improve
# Epoch 52/100
# 2089/2089 [==============================] - 13s 6ms/step - loss: 1.1463 - acc: 0.4931 - val_loss: 1.3237 - val_acc: 0.4173
#
# Epoch 00052: val_acc did not improve
# Epoch 53/100
# 2089/2089 [==============================] - 13s 6ms/step - loss: 1.1623 - acc: 0.4883 - val_loss: 1.3206 - val_acc: 0.4119
#
# Epoch 00053: val_acc did not improve
# Epoch 54/100
# 2089/2089 [==============================] - 14s 7ms/step - loss: 1.1274 - acc: 0.5165 - val_loss: 1.3200 - val_acc: 0.3984
#
# Epoch 00054: val_acc did not improve
# Epoch 55/100
# 2089/2089 [==============================] - 14s 7ms/step - loss: 1.1332 - acc: 0.5002 - val_loss: 1.3065 - val_acc: 0.4201
#
# Epoch 00055: val_acc did not improve
# Epoch 56/100
# 2089/2089 [==============================] - 12s 6ms/step - loss: 1.1333 - acc: 0.5089 - val_loss: 1.3024 - val_acc: 0.4282
#
# Epoch 00056: val_acc improved from 0.42818 to 0.42818, saving model to GRU_model.hdf5
# Epoch 57/100
# 2089/2089 [==============================] - 12s 6ms/step - loss: 1.1256 - acc: 0.5036 - val_loss: 1.3154 - val_acc: 0.4201
#
# Epoch 00057: val_acc did not improve
# Epoch 58/100
# 2089/2089 [==============================] - 14s 6ms/step - loss: 1.1078 - acc: 0.5151 - val_loss: 1.3070 - val_acc: 0.4146
#
# Epoch 00058: val_acc did not improve
# Epoch 59/100
# 2089/2089 [==============================] - 15s 7ms/step - loss: 1.1184 - acc: 0.5165 - val_loss: 1.3175 - val_acc: 0.4092
#
# Epoch 00059: val_acc did not improve
# Epoch 60/100
# 2089/2089 [==============================] - 13s 6ms/step - loss: 1.1191 - acc: 0.5199 - val_loss: 1.2896 - val_acc: 0.4255
#
# Epoch 00060: val_acc did not improve
# Epoch 61/100
# 2089/2089 [==============================] - 13s 6ms/step - loss: 1.1128 - acc: 0.5132 - val_loss: 1.3121 - val_acc: 0.4119
#
# Epoch 00061: val_acc did not improve
# Epoch 62/100
# 2089/2089 [==============================] - 14s 7ms/step - loss: 1.0963 - acc: 0.5337 - val_loss: 1.3012 - val_acc: 0.4173
#
# Epoch 00062: val_acc did not improve
# Epoch 63/100
# 2089/2089 [==============================] - 13s 6ms/step - loss: 1.0873 - acc: 0.5208 - val_loss: 1.3181 - val_acc: 0.4228
#
# Epoch 00063: val_acc did not improve
# Epoch 64/100
# 2089/2089 [==============================] - 13s 6ms/step - loss: 1.0863 - acc: 0.5366 - val_loss: 1.2916 - val_acc: 0.3984
#
# Epoch 00064: val_acc did not improve
# Epoch 65/100
# 2089/2089 [==============================] - 13s 6ms/step - loss: 1.0674 - acc: 0.5596 - val_loss: 1.2967 - val_acc: 0.3957
#
# Epoch 00065: val_acc did not improve
# Epoch 66/100
# 2089/2089 [==============================] - 13s 6ms/step - loss: 1.0595 - acc: 0.5404 - val_loss: 1.3039 - val_acc: 0.3875
#
# Epoch 00066: val_acc did not improve
# Epoch 67/100
# 2089/2089 [==============================] - 12s 6ms/step - loss: 1.0547 - acc: 0.5596 - val_loss: 1.3021 - val_acc: 0.4038
#
# Epoch 00067: val_acc did not improve
# Epoch 68/100
# 2089/2089 [==============================] - 14s 7ms/step - loss: 1.0501 - acc: 0.5591 - val_loss: 1.2941 - val_acc: 0.4065
#
# Epoch 00068: val_acc did not improve
# Epoch 69/100
# 2089/2089 [==============================] - 13s 6ms/step - loss: 1.0516 - acc: 0.5495 - val_loss: 1.2869 - val_acc: 0.4092
#
# Epoch 00069: val_acc did not improve
# Epoch 70/100
# 2089/2089 [==============================] - 13s 6ms/step - loss: 1.0177 - acc: 0.5835 - val_loss: 1.2910 - val_acc: 0.4173
#
# Epoch 00070: val_acc did not improve
# Epoch 71/100
# 2089/2089 [==============================] - 13s 6ms/step - loss: 1.0255 - acc: 0.5692 - val_loss: 1.2894 - val_acc: 0.4092
#
# Epoch 00071: val_acc did not improve
# Epoch 72/100
# 2089/2089 [==============================] - 12s 6ms/step - loss: 1.0261 - acc: 0.5615 - val_loss: 1.2981 - val_acc: 0.4065
#
# Epoch 00072: val_acc did not improve
# Epoch 73/100
# 2089/2089 [==============================] - 13s 6ms/step - loss: 1.0119 - acc: 0.5740 - val_loss: 1.3051 - val_acc: 0.4173
#
# Epoch 00073: val_acc did not improve
# Epoch 74/100
# 2089/2089 [==============================] - 17s 8ms/step - loss: 1.0024 - acc: 0.5864 - val_loss: 1.3092 - val_acc: 0.4065
#
# Epoch 00074: val_acc did not improve
# Epoch 75/100
# 2089/2089 [==============================] - 14s 7ms/step - loss: 1.0060 - acc: 0.5816 - val_loss: 1.3107 - val_acc: 0.4173
#
# Epoch 00075: val_acc did not improve
# Epoch 76/100
# 2089/2089 [==============================] - 14s 7ms/step - loss: 0.9815 - acc: 0.5993 - val_loss: 1.2982 - val_acc: 0.4038
#
# Epoch 00076: val_acc did not improve
# Epoch 77/100
# 2089/2089 [==============================] - 15s 7ms/step - loss: 0.9651 - acc: 0.5955 - val_loss: 1.3096 - val_acc: 0.4201
#
# Epoch 00077: val_acc did not improve
# Epoch 78/100
# 2089/2089 [==============================] - 13s 6ms/step - loss: 0.9681 - acc: 0.6022 - val_loss: 1.3119 - val_acc: 0.4065
#
# Epoch 00078: val_acc did not improve
# Epoch 79/100
# 2089/2089 [==============================] - 13s 6ms/step - loss: 0.9629 - acc: 0.6027 - val_loss: 1.3200 - val_acc: 0.4038
#
# Epoch 00079: val_acc did not improve
# Epoch 80/100
# 2089/2089 [==============================] - 13s 6ms/step - loss: 0.9389 - acc: 0.6123 - val_loss: 1.3271 - val_acc: 0.4119
#
# Epoch 00080: val_acc did not improve
# Epoch 81/100
# 2089/2089 [==============================] - 13s 6ms/step - loss: 0.9366 - acc: 0.6170 - val_loss: 1.3375 - val_acc: 0.4146
#
# Epoch 00081: val_acc did not improve
# Epoch 82/100
# 2089/2089 [==============================] - 12s 6ms/step - loss: 0.9350 - acc: 0.6314 - val_loss: 1.3344 - val_acc: 0.4201
#
# Epoch 00082: val_acc did not improve
# Epoch 83/100
# 2089/2089 [==============================] - 13s 6ms/step - loss: 0.9140 - acc: 0.6309 - val_loss: 1.3329 - val_acc: 0.4173
#
# Epoch 00083: val_acc did not improve
# Epoch 84/100
# 2089/2089 [==============================] - 13s 6ms/step - loss: 0.9039 - acc: 0.6314 - val_loss: 1.3345 - val_acc: 0.4282
#
# Epoch 00084: val_acc improved from 0.42818 to 0.42818, saving model to GRU_model.hdf5
# Epoch 85/100
# 2089/2089 [==============================] - 13s 6ms/step - loss: 0.8958 - acc: 0.6328 - val_loss: 1.3435 - val_acc: 0.4119
#
# Epoch 00085: val_acc did not improve
# Epoch 86/100
# 2089/2089 [==============================] - 14s 7ms/step - loss: 0.9037 - acc: 0.6304 - val_loss: 1.3475 - val_acc: 0.4173
#
# Epoch 00086: val_acc did not improve
# Epoch 87/100
# 2089/2089 [==============================] - 15s 7ms/step - loss: 0.8831 - acc: 0.6424 - val_loss: 1.3527 - val_acc: 0.4119
#
# Epoch 00087: val_acc did not improve
# Epoch 88/100
# 2089/2089 [==============================] - 13s 6ms/step - loss: 0.8706 - acc: 0.6477 - val_loss: 1.3626 - val_acc: 0.4201
#
# Epoch 00088: val_acc did not improve
# Epoch 89/100
# 2089/2089 [==============================] - 13s 6ms/step - loss: 0.8597 - acc: 0.6596 - val_loss: 1.3701 - val_acc: 0.4011
#
# Epoch 00089: val_acc did not improve
# Epoch 90/100
# 2089/2089 [==============================] - 13s 6ms/step - loss: 0.8467 - acc: 0.6620 - val_loss: 1.3626 - val_acc: 0.4011
#
# Epoch 00090: val_acc did not improve
# Epoch 91/100
# 2089/2089 [==============================] - 13s 6ms/step - loss: 0.8375 - acc: 0.6601 - val_loss: 1.3732 - val_acc: 0.4092
#
# Epoch 00091: val_acc did not improve
# Epoch 92/100
# 2089/2089 [==============================] - 12s 6ms/step - loss: 0.8138 - acc: 0.6778 - val_loss: 1.3802 - val_acc: 0.4119
#
# Epoch 00092: val_acc did not improve
# Epoch 93/100
# 2089/2089 [==============================] - 12s 6ms/step - loss: 0.8211 - acc: 0.6663 - val_loss: 1.3909 - val_acc: 0.4119
#
# Epoch 00093: val_acc did not improve
# Epoch 94/100
# 2089/2089 [==============================] - 13s 6ms/step - loss: 0.8029 - acc: 0.6817 - val_loss: 1.3948 - val_acc: 0.4336
#
# Epoch 00094: val_acc improved from 0.42818 to 0.43360, saving model to GRU_model.hdf5
# Epoch 95/100
# 2089/2089 [==============================] - 13s 6ms/step - loss: 0.8027 - acc: 0.6774 - val_loss: 1.3935 - val_acc: 0.4119
#
# Epoch 00095: val_acc did not improve
# Epoch 96/100
# 2089/2089 [==============================] - 15s 7ms/step - loss: 0.8157 - acc: 0.6654 - val_loss: 1.3932 - val_acc: 0.4282
#
# Epoch 00096: val_acc did not improve
# Epoch 97/100
# 2089/2089 [==============================] - 13s 6ms/step - loss: 0.7644 - acc: 0.6912 - val_loss: 1.4208 - val_acc: 0.4038
#
# Epoch 00097: val_acc did not improve
# Epoch 98/100
# 2089/2089 [==============================] - 14s 7ms/step - loss: 0.7745 - acc: 0.6965 - val_loss: 1.4405 - val_acc: 0.4038
#
# Epoch 00098: val_acc did not improve
# Epoch 99/100
# 2089/2089 [==============================] - 13s 6ms/step - loss: 0.7620 - acc: 0.7022 - val_loss: 1.4432 - val_acc: 0.3957
#
# Epoch 00099: val_acc did not improve

# %%
# list all data in history
print(history.history.keys())

# summarize history for accuracy
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# summarize history for loss
plt.plot(history.history['loss'],'o')
plt.plot(history.history['val_loss'],'o')
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()
# Out:
# dict_keys(['val_loss', 'val_acc', 'loss', 'acc'])

# %%
# evaluate model on entire training set
model = load_model('GRU_model.hdf5')
model.evaluate(X_train_sub,y_train,batch_size=N_train)
# Out:
# 2458/2458 [==============================] - 4s 1ms/step
# [0.5949629545211792, 0.83197718858718872]

# %%
# evaluate model on test set
model.evaluate(X_test_sub,y_test,batch_size=N_test)
# Out:
# 100/100 [==============================] - 0s 1ms/step
# [1.407508373260498, 0.46000000834465027]
