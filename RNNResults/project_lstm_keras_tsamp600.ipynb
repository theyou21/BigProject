# %%
from keras.models import Sequential
from keras.layers import LSTM, GRU, Dense, Dropout, TimeDistributed, BatchNormalization, Flatten, Activation
from keras import regularizers
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.models import load_model
import numpy as np
import h5py
import matplotlib.pyplot as plt
from data_utils import get_data
from sklearn import preprocessing
from functools import reduce
from scipy.fftpack import dct, idct
from scipy import signal
# Out:
# Using TensorFlow backend.

# %%
# Load data from all .mat files, combine them, eliminate EOG signals, shuffle and 
# seperate training data, validation data and testing data.
# Also do mean subtraction on x.

data = get_data('project_datasets',num_validation=0, num_test=100, subtract_mean=False, subtract_axis=1,
                transpose=True)
for k in data.keys():
    print('{}: {} '.format(k, data[k].shape))
# Out:
# X_train: (2458, 1000, 22)
# y_train: (2458,)
# X_val: (0, 1000, 22)
# y_val: (0,)
# X_test: (100, 1000, 22)
# y_test: (100,)

# %%
# substract data from list
X_train = data.get('X_train')
y_train = data.get('y_train')
#X_val = data.get('X_val')
#y_val = data.get('y_val')
X_test = data.get('X_test')
y_test = data.get('y_test')

# get data dimension
N_train, T_train, C_train = data.get('X_train').shape
N_val, T_val, C_val = data.get('X_val').shape
N_test, T_test, C_test = data.get('X_test').shape

# add dummy zeros for y classification
lb = preprocessing.LabelBinarizer()
lb.fit([0, 1, 2, 3,])
lb.classes_
y_train = lb.transform(y_train)
if (N_val > 0): y_val = lb.transform(y_val)
y_test = lb.transform(y_test)

# %%
# Filtering through FFT(discrete cosine transform)

def filter(x, low=0, high=1, plot=False):
    N = x.shape[0]
    t = np.linspace(0,N,N)
    y = dct(x, norm='ortho')
    window = np.zeros(N)
    window[int(low*N):int(high*N)] = 1
    yr = idct(y*window, norm='ortho')
    sum(abs(x-yr)**2) / sum(abs(x)**2)
    if plot:
        plt.plot(t, x, '-b')
        plt.plot(t, yr, 'r')
    return x

# Filter band
low_freq = 0.02
high_freq = 0.4

for i in np.arange(N_train):
    for j in np.arange(C_train):
       X_train[i,:,j]= filter(X_train[i,:,j],low_freq,high_freq)
for i in np.arange(N_val):
    for j in arange(C_val):
       X_val[i,:,j]= filter(X_val[i,:,j],low_freq,high_freq)
    
for i in np.arange(N_test):
    for j in np.arange(C_test):
       X_test[i,:,j]= filter(X_test[i,:,j],low_freq,high_freq)

# %%
# Downsampling in time through FFT

t_sample = 600
X_train_sub = signal.resample(X_train,t_sample,axis=1)
if (N_val > 0): X_val_sub = signal.resample(X_val,t_sample,axis=1)
X_test_sub = signal.resample(X_test,t_sample,axis=1)

# show a downsampling example
plt.plot(np.linspace(0,1,T_train),X_train[5,:,5],'-b')
plt.plot(np.linspace(0,1,t_sample),X_train_sub[5,:,5],'-r')

# %%
print(X_train_sub.shape)
# Out:
# (2458, 600, 22)

# %%
# # normalize data across the time sequence dimension only
# scaler = preprocessing.MinMaxScaler()
# for i in range(N_train):
#     scaler.fit(X_train[i,:,:])
#     X_train[i,:,:] = scaler.transform(X_train[i,:,:])
    
# for i in range(N_val):
#     scaler.fit(X_val[i,:,:])
#     X_val[i,:,:] = scaler.transform(X_val[i,:,:])

# %%
# def downsample(data, mul=10, enableTrunc = False):
#     assert data.shape[0] % mul == 0 or  enableTrunc, "Can't downsample without data truncation.\
#                                                 \n Set another value of mul or set enableTrunc = True"
#     outdata = []
#     for i in range(data.shape[0]//mul):
#         outdata.append(np.mean(data[i*mul:(i+1)*mul,...], axis=0, keepdims=True))
#     outdata = reduce(lambda a,b: np.append(a,b,0), outdata)
    
#     return outdata
# span = 2
# X_train_sub = np.expand_dims(downsample(X_train[0,:,:], mul=span),axis=0)
# for n in np.arange(1,X_train.shape[0]):
#     X_train_sub = np.append(X_train_sub,
#                             np.expand_dims(downsample(X_train[n,:,:], mul=span),axis=0),axis=0)

# X_val_sub = np.expand_dims(downsample(X_val[0,:,:], mul=span),axis=0)
# for n in np.arange(1,X_val.shape[0]):
#     X_val_sub = np.append(X_val_sub,
#                             np.expand_dims(downsample(X_val[n,:,:], mul=span),axis=0),axis=0)

# print('X_train_sub: ', X_train_sub.shape)
# print('X_val_sub: ', X_val_sub.shape)

# %%
# Expected input shape: ([batch_size], timesteps, data_dim)
# Note that we have to provide the full batch_input_shape if the network is stateful.
# the sample of index i in batch k is the follow-up for the sample i in batch k-1.

# perhaps should try masking layer

data_dim = C_train
seq_split = 1 # Set to one when using FFT to down sample
seq_len = int(X_train_sub.shape[1]*seq_split)
timesteps = seq_len
num_classes = 4
batch_size = 200
num_epoch = 100

model = Sequential()
#1
model.add(LSTM(200, return_sequences=True, stateful=False,
          recurrent_dropout=0.5, dropout = 0.5, input_shape=(timesteps, data_dim)))

#2
model.add(LSTM(100, return_sequences=True, stateful=False,
          recurrent_dropout=0.5, dropout = 0.5))

#3
model.add(LSTM(50, return_sequences=True, stateful=False,
          recurrent_dropout=0.5, dropout = 0.5))
model.add(Flatten())

#4
model.add(Dense(100))
model.add(BatchNormalization(axis=-1))
model.add(Activation('relu'))
model.add(Dropout(0.5))

#5
model.add(Dense(num_classes, activation='softmax'))

model.compile(loss='categorical_crossentropy',
              optimizer='rmsprop',
              metrics=['accuracy'])

# define early stopping callback
earlystop = EarlyStopping(monitor='val_loss', min_delta=0.001, patience=70, mode='auto')

# saves the model weights after each epoch if the validation loss decreased
checkpointer = ModelCheckpoint(filepath='LSTM_model.hdf5', monitor='val_acc', verbose=1, save_best_only=True)

callbacks_list = [earlystop, checkpointer]

# %%
history = model.fit(X_train_sub[:,:seq_len,:], y_train,
                    batch_size=batch_size, epochs=num_epoch, shuffle=True,
                    validation_split = 0.15, callbacks=callbacks_list)
# Out:
# Train on 2089 samples, validate on 369 samples
# Epoch 1/100
# 2089/2089 [==============================] - 115s 55ms/step - loss: 1.9950 - acc: 0.2719 - val_loss: 1.5157 - val_acc: 0.3062
#
# Epoch 00001: val_acc improved from -inf to 0.30623, saving model to LSTM_model.hdf5
# Epoch 2/100
# 2089/2089 [==============================] - 105s 50ms/step - loss: 1.7082 - acc: 0.2815 - val_loss: 1.6960 - val_acc: 0.3333
#
# Epoch 00002: val_acc improved from 0.30623 to 0.33333, saving model to LSTM_model.hdf5
# Epoch 3/100
# 2089/2089 [==============================] - 103s 49ms/step - loss: 1.6598 - acc: 0.2848 - val_loss: 1.6176 - val_acc: 0.3469
#
# Epoch 00003: val_acc improved from 0.33333 to 0.34688, saving model to LSTM_model.hdf5
# Epoch 4/100
# 2089/2089 [==============================] - 102s 49ms/step - loss: 1.5748 - acc: 0.3045 - val_loss: 1.6478 - val_acc: 0.3388
#
# Epoch 00004: val_acc did not improve
# Epoch 5/100
# 2089/2089 [==============================] - 101s 48ms/step - loss: 1.5494 - acc: 0.3231 - val_loss: 1.6744 - val_acc: 0.3523
#
# Epoch 00005: val_acc improved from 0.34688 to 0.35230, saving model to LSTM_model.hdf5
# Epoch 6/100
# 2089/2089 [==============================] - 101s 49ms/step - loss: 1.5085 - acc: 0.3375 - val_loss: 1.6802 - val_acc: 0.3360
#
# Epoch 00006: val_acc did not improve
# Epoch 7/100
# 2089/2089 [==============================] - 100s 48ms/step - loss: 1.4971 - acc: 0.3370 - val_loss: 1.5301 - val_acc: 0.3659
#
# Epoch 00007: val_acc improved from 0.35230 to 0.36585, saving model to LSTM_model.hdf5
# Epoch 8/100
# 2089/2089 [==============================] - 102s 49ms/step - loss: 1.4256 - acc: 0.3576 - val_loss: 1.5780 - val_acc: 0.3604
#
# Epoch 00008: val_acc did not improve
# Epoch 9/100
# 2089/2089 [==============================] - 103s 49ms/step - loss: 1.4366 - acc: 0.3542 - val_loss: 1.5497 - val_acc: 0.3496
#
# Epoch 00009: val_acc did not improve
# Epoch 10/100
# 2089/2089 [==============================] - 102s 49ms/step - loss: 1.3967 - acc: 0.3657 - val_loss: 1.5127 - val_acc: 0.3631
#
# Epoch 00010: val_acc did not improve
# Epoch 11/100
# 2089/2089 [==============================] - 101s 48ms/step - loss: 1.3603 - acc: 0.4002 - val_loss: 1.4749 - val_acc: 0.3686
#
# Epoch 00011: val_acc improved from 0.36585 to 0.36856, saving model to LSTM_model.hdf5
# Epoch 12/100
# 2089/2089 [==============================] - 102s 49ms/step - loss: 1.3621 - acc: 0.3820 - val_loss: 1.5096 - val_acc: 0.3631
#
# Epoch 00012: val_acc did not improve
# Epoch 13/100
# 2089/2089 [==============================] - 101s 48ms/step - loss: 1.2921 - acc: 0.4126 - val_loss: 1.5481 - val_acc: 0.3577
#
# Epoch 00013: val_acc did not improve
# Epoch 14/100
# 2089/2089 [==============================] - 101s 49ms/step - loss: 1.2994 - acc: 0.4146 - val_loss: 1.4802 - val_acc: 0.3604
#
# Epoch 00014: val_acc did not improve
# Epoch 15/100
# 2089/2089 [==============================] - 103s 49ms/step - loss: 1.2424 - acc: 0.4366 - val_loss: 1.4852 - val_acc: 0.3848
#
# Epoch 00015: val_acc improved from 0.36856 to 0.38482, saving model to LSTM_model.hdf5
# Epoch 16/100
# 2089/2089 [==============================] - 103s 49ms/step - loss: 1.2512 - acc: 0.4318 - val_loss: 1.4821 - val_acc: 0.4011
#
# Epoch 00016: val_acc improved from 0.38482 to 0.40108, saving model to LSTM_model.hdf5
# Epoch 17/100
# 2089/2089 [==============================] - 102s 49ms/step - loss: 1.2141 - acc: 0.4576 - val_loss: 1.4844 - val_acc: 0.3957
#
# Epoch 00017: val_acc did not improve
# Epoch 18/100
# 2089/2089 [==============================] - 101s 48ms/step - loss: 1.1668 - acc: 0.4749 - val_loss: 1.5042 - val_acc: 0.3930
#
# Epoch 00018: val_acc did not improve
# Epoch 19/100
# 2089/2089 [==============================] - 102s 49ms/step - loss: 1.1657 - acc: 0.4840 - val_loss: 1.4427 - val_acc: 0.3821
#
# Epoch 00019: val_acc did not improve
# Epoch 20/100
# 2089/2089 [==============================] - 100s 48ms/step - loss: 1.1497 - acc: 0.4978 - val_loss: 1.4753 - val_acc: 0.3875
#
# Epoch 00020: val_acc did not improve
# Epoch 21/100
# 2089/2089 [==============================] - 103s 49ms/step - loss: 1.1236 - acc: 0.5199 - val_loss: 1.4451 - val_acc: 0.3631
#
# Epoch 00021: val_acc did not improve
# Epoch 22/100
# 2089/2089 [==============================] - 102s 49ms/step - loss: 1.1033 - acc: 0.5141 - val_loss: 1.4159 - val_acc: 0.3930
#
# Epoch 00022: val_acc did not improve
# Epoch 23/100
# 2089/2089 [==============================] - 103s 49ms/step - loss: 1.0562 - acc: 0.5548 - val_loss: 1.4201 - val_acc: 0.3821
#
# Epoch 00023: val_acc did not improve
# Epoch 24/100
# 2089/2089 [==============================] - 101s 48ms/step - loss: 1.0477 - acc: 0.5620 - val_loss: 1.4316 - val_acc: 0.3875
#
# Epoch 00024: val_acc did not improve
# Epoch 25/100
# 2089/2089 [==============================] - 102s 49ms/step - loss: 1.0320 - acc: 0.5515 - val_loss: 1.4185 - val_acc: 0.4011
#
# Epoch 00025: val_acc did not improve
# Epoch 26/100
# 2089/2089 [==============================] - 102s 49ms/step - loss: 0.9957 - acc: 0.5850 - val_loss: 1.4154 - val_acc: 0.3957
#
# Epoch 00026: val_acc did not improve
# Epoch 27/100
# 2089/2089 [==============================] - 101s 48ms/step - loss: 0.9815 - acc: 0.5984 - val_loss: 1.4046 - val_acc: 0.3984
#
# Epoch 00027: val_acc did not improve
# Epoch 28/100
# 2089/2089 [==============================] - 102s 49ms/step - loss: 0.9547 - acc: 0.6123 - val_loss: 1.4221 - val_acc: 0.4146
#
# Epoch 00028: val_acc improved from 0.40108 to 0.41463, saving model to LSTM_model.hdf5
# Epoch 29/100
# 2089/2089 [==============================] - 103s 49ms/step - loss: 0.9149 - acc: 0.6304 - val_loss: 1.4038 - val_acc: 0.4119
#
# Epoch 00029: val_acc did not improve
# Epoch 30/100
# 2089/2089 [==============================] - 103s 49ms/step - loss: 0.8962 - acc: 0.6271 - val_loss: 1.3997 - val_acc: 0.4255
#
# Epoch 00030: val_acc improved from 0.41463 to 0.42547, saving model to LSTM_model.hdf5
# Epoch 31/100
# 2089/2089 [==============================] - 100s 48ms/step - loss: 0.9002 - acc: 0.6362 - val_loss: 1.3756 - val_acc: 0.4146
#
# Epoch 00031: val_acc did not improve
# Epoch 32/100
# 2089/2089 [==============================] - 102s 49ms/step - loss: 0.8413 - acc: 0.6649 - val_loss: 1.4042 - val_acc: 0.4309
#
# Epoch 00032: val_acc improved from 0.42547 to 0.43089, saving model to LSTM_model.hdf5
# Epoch 33/100
# 2089/2089 [==============================] - 101s 48ms/step - loss: 0.8194 - acc: 0.6802 - val_loss: 1.4275 - val_acc: 0.4255
#
# Epoch 00033: val_acc did not improve
# Epoch 34/100
# 2089/2089 [==============================] - 107s 51ms/step - loss: 0.7921 - acc: 0.6898 - val_loss: 1.4078 - val_acc: 0.4417
#
# Epoch 00034: val_acc improved from 0.43089 to 0.44173, saving model to LSTM_model.hdf5
# Epoch 35/100
# 2089/2089 [==============================] - 103s 49ms/step - loss: 0.7579 - acc: 0.7109 - val_loss: 1.4146 - val_acc: 0.4255
#
# Epoch 00035: val_acc did not improve
# Epoch 36/100
# 2089/2089 [==============================] - 103s 49ms/step - loss: 0.7343 - acc: 0.7152 - val_loss: 1.4141 - val_acc: 0.4201
#
# Epoch 00036: val_acc did not improve
# Epoch 37/100
# 2089/2089 [==============================] - 103s 49ms/step - loss: 0.7311 - acc: 0.7137 - val_loss: 1.4623 - val_acc: 0.4119
#
# Epoch 00037: val_acc did not improve
# Epoch 38/100
# 2089/2089 [==============================] - 101s 48ms/step - loss: 0.6818 - acc: 0.7425 - val_loss: 1.4510 - val_acc: 0.4092
#
# Epoch 00038: val_acc did not improve
# Epoch 39/100
# 2089/2089 [==============================] - 103s 49ms/step - loss: 0.6720 - acc: 0.7520 - val_loss: 1.4519 - val_acc: 0.4119
#
# Epoch 00039: val_acc did not improve
# Epoch 40/100
# 2089/2089 [==============================] - 100s 48ms/step - loss: 0.6254 - acc: 0.7779 - val_loss: 1.4745 - val_acc: 0.4173
#
# Epoch 00040: val_acc did not improve
# Epoch 41/100
# 2089/2089 [==============================] - 102s 49ms/step - loss: 0.6236 - acc: 0.7731 - val_loss: 1.5367 - val_acc: 0.3957
#
# Epoch 00041: val_acc did not improve
# Epoch 42/100
# 2089/2089 [==============================] - 104s 50ms/step - loss: 0.6085 - acc: 0.7664 - val_loss: 1.5375 - val_acc: 0.3902
#
# Epoch 00042: val_acc did not improve
# Epoch 43/100
# 2089/2089 [==============================] - 102s 49ms/step - loss: 0.5550 - acc: 0.8119 - val_loss: 1.5368 - val_acc: 0.3902
# Epoch 00043: val_acc did not improve
# Epoch 44/100
# 2089/2089 [==============================] - 105s 50ms/step - loss: 0.5296 - acc: 0.8171 - val_loss: 1.5668 - val_acc: 0.4011
#
# Epoch 00044: val_acc did not improve
# Epoch 45/100
# 2089/2089 [==============================] - 111s 53ms/step - loss: 0.4872 - acc: 0.8363 - val_loss: 1.5778 - val_acc: 0.4038
#
# Epoch 00045: val_acc did not improve
# Epoch 46/100
# 2089/2089 [==============================] - 102s 49ms/step - loss: 0.4957 - acc: 0.8262 - val_loss: 1.6187 - val_acc: 0.3875
#
# Epoch 00046: val_acc did not improve
# Epoch 47/100
# 2089/2089 [==============================] - 106s 51ms/step - loss: 0.4563 - acc: 0.8506 - val_loss: 1.6614 - val_acc: 0.4011
#
# Epoch 00047: val_acc did not improve
# Epoch 48/100
# 2089/2089 [==============================] - 103s 49ms/step - loss: 0.4233 - acc: 0.8631 - val_loss: 1.6602 - val_acc: 0.3902
#
# Epoch 00048: val_acc did not improve
# Epoch 49/100
# 2089/2089 [==============================] - 107s 51ms/step - loss: 0.4085 - acc: 0.8712 - val_loss: 1.6852 - val_acc: 0.3957
#
# Epoch 00049: val_acc did not improve
# Epoch 50/100
# 2089/2089 [==============================] - 106s 51ms/step - loss: 0.3941 - acc: 0.8679 - val_loss: 1.7230 - val_acc: 0.3686
#
# Epoch 00050: val_acc did not improve
# Epoch 51/100
# 2089/2089 [==============================] - 107s 51ms/step - loss: 0.3347 - acc: 0.8947 - val_loss: 1.7612 - val_acc: 0.3713
#
# Epoch 00051: val_acc did not improve
# Epoch 52/100
# 2089/2089 [==============================] - 105s 50ms/step - loss: 0.3322 - acc: 0.9004 - val_loss: 1.7501 - val_acc: 0.3848
#
# Epoch 00052: val_acc did not improve
# Epoch 53/100
# 2089/2089 [==============================] - 104s 50ms/step - loss: 0.3282 - acc: 0.9033 - val_loss: 1.7674 - val_acc: 0.4038
#
# Epoch 00053: val_acc did not improve
# Epoch 54/100
# 2089/2089 [==============================] - 103s 49ms/step - loss: 0.3154 - acc: 0.9014 - val_loss: 1.8101 - val_acc: 0.3984
#
# Epoch 00054: val_acc did not improve
# Epoch 55/100
# 2089/2089 [==============================] - 106s 51ms/step - loss: 0.2718 - acc: 0.9258 - val_loss: 1.8475 - val_acc: 0.4092
#
# Epoch 00055: val_acc did not improve
# Epoch 56/100
# 2089/2089 [==============================] - 105s 50ms/step - loss: 0.2568 - acc: 0.9253 - val_loss: 1.8622 - val_acc: 0.3930
#
# Epoch 00056: val_acc did not improve
# Epoch 57/100
# 2089/2089 [==============================] - 108s 52ms/step - loss: 0.2560 - acc: 0.9263 - val_loss: 1.8610 - val_acc: 0.3930
#
# Epoch 00057: val_acc did not improve
# Epoch 58/100
# 2089/2089 [==============================] - 105s 50ms/step - loss: 0.2473 - acc: 0.9268 - val_loss: 1.9408 - val_acc: 0.3767
#
# Epoch 00058: val_acc did not improve
# Epoch 59/100
# 2089/2089 [==============================] - 109s 52ms/step - loss: 0.2303 - acc: 0.9292 - val_loss: 1.9278 - val_acc: 0.3875
#
# Epoch 00059: val_acc did not improve
# Epoch 60/100
# 2089/2089 [==============================] - 83s 40ms/step - loss: 0.2202 - acc: 0.9397 - val_loss: 1.9687 - val_acc: 0.3740
#
# Epoch 00060: val_acc did not improve
# Epoch 61/100
# 2089/2089 [==============================] - 46s 22ms/step - loss: 0.1949 - acc: 0.9430 - val_loss: 1.9907 - val_acc: 0.3848
#
# Epoch 00061: val_acc did not improve
# Epoch 62/100
# 2089/2089 [==============================] - 46s 22ms/step - loss: 0.1910 - acc: 0.9426 - val_loss: 2.0219 - val_acc: 0.3767
#
# Epoch 00062: val_acc did not improve
# Epoch 63/100
# 2089/2089 [==============================] - 44s 21ms/step - loss: 0.1851 - acc: 0.9445 - val_loss: 1.9924 - val_acc: 0.3740
#
# Epoch 00063: val_acc did not improve
# Epoch 64/100
# 2089/2089 [==============================] - 44s 21ms/step - loss: 0.1706 - acc: 0.9555 - val_loss: 2.0712 - val_acc: 0.3957
#
# Epoch 00064: val_acc did not improve
# Epoch 65/100
# 2089/2089 [==============================] - 47s 22ms/step - loss: 0.1722 - acc: 0.9440 - val_loss: 2.1236 - val_acc: 0.3821
#
# Epoch 00065: val_acc did not improve
# Epoch 66/100
# 2089/2089 [==============================] - 45s 22ms/step - loss: 0.1538 - acc: 0.9627 - val_loss: 2.1318 - val_acc: 0.3821
#
# Epoch 00066: val_acc did not improve
# Epoch 67/100
# 2089/2089 [==============================] - 45s 22ms/step - loss: 0.1470 - acc: 0.9607 - val_loss: 2.1862 - val_acc: 0.3631
#
# Epoch 00067: val_acc did not improve
# Epoch 68/100
# 2089/2089 [==============================] - 47s 23ms/step - loss: 0.1378 - acc: 0.9646 - val_loss: 2.2039 - val_acc: 0.3740
#
# Epoch 00068: val_acc did not improve
# Epoch 69/100
# 2089/2089 [==============================] - 46s 22ms/step - loss: 0.1455 - acc: 0.9612 - val_loss: 2.2178 - val_acc: 0.3740
#
# Epoch 00069: val_acc did not improve
# Epoch 70/100
# 2089/2089 [==============================] - 47s 23ms/step - loss: 0.1238 - acc: 0.9636 - val_loss: 2.2645 - val_acc: 0.3713
#
# Epoch 00070: val_acc did not improve
# Epoch 71/100
# 2089/2089 [==============================] - 45s 22ms/step - loss: 0.1149 - acc: 0.9713 - val_loss: 2.3201 - val_acc: 0.3875
#
# Epoch 00071: val_acc did not improve
# Epoch 72/100
# 2089/2089 [==============================] - 45s 21ms/step - loss: 0.1236 - acc: 0.9636 - val_loss: 2.3090 - val_acc: 0.3767
#
# Epoch 00072: val_acc did not improve
# Epoch 73/100
# 2089/2089 [==============================] - 46s 22ms/step - loss: 0.1210 - acc: 0.9641 - val_loss: 2.3163 - val_acc: 0.3902
#
# Epoch 00073: val_acc did not improve
# Epoch 74/100
# 2089/2089 [==============================] - 45s 22ms/step - loss: 0.1078 - acc: 0.9689 - val_loss: 2.3833 - val_acc: 0.3875
#
# Epoch 00074: val_acc did not improve
# Epoch 75/100
# 2089/2089 [==============================] - 45s 21ms/step - loss: 0.1083 - acc: 0.9708 - val_loss: 2.4472 - val_acc: 0.3740
#
# Epoch 00075: val_acc did not improve
# Epoch 76/100
# 2089/2089 [==============================] - 52s 25ms/step - loss: 0.0936 - acc: 0.9751 - val_loss: 2.4523 - val_acc: 0.3767
#
# Epoch 00076: val_acc did not improve
# Epoch 77/100
# 2089/2089 [==============================] - 48s 23ms/step - loss: 0.0907 - acc: 0.9756 - val_loss: 2.4883 - val_acc: 0.3740
#
# Epoch 00077: val_acc did not improve
# Epoch 78/100
# 2089/2089 [==============================] - 46s 22ms/step - loss: 0.0821 - acc: 0.9804 - val_loss: 2.4598 - val_acc: 0.3821
#
# Epoch 00078: val_acc did not improve
# Epoch 79/100
# 2089/2089 [==============================] - 44s 21ms/step - loss: 0.0849 - acc: 0.9789 - val_loss: 2.4553 - val_acc: 0.3875
#
# Epoch 00079: val_acc did not improve
# Epoch 80/100
# 2089/2089 [==============================] - 45s 21ms/step - loss: 0.0847 - acc: 0.9761 - val_loss: 2.5091 - val_acc: 0.3902
#
# Epoch 00080: val_acc did not improve
# Epoch 81/100
# 2089/2089 [==============================] - 45s 22ms/step - loss: 0.0756 - acc: 0.9799 - val_loss: 2.5384 - val_acc: 0.3848
#
# Epoch 00081: val_acc did not improve
# Epoch 82/100
# 2089/2089 [==============================] - 44s 21ms/step - loss: 0.0718 - acc: 0.9828 - val_loss: 2.5032 - val_acc: 0.3848
#
# Epoch 00082: val_acc did not improve
# Epoch 83/100
# 2089/2089 [==============================] - 46s 22ms/step - loss: 0.0755 - acc: 0.9789 - val_loss: 2.6089 - val_acc: 0.3631
#
# Epoch 00083: val_acc did not improve
# Epoch 84/100
# 2089/2089 [==============================] - 43s 21ms/step - loss: 0.0803 - acc: 0.9765 - val_loss: 2.6228 - val_acc: 0.3821
#
# Epoch 00084: val_acc did not improve
# Epoch 85/100
# 2089/2089 [==============================] - 44s 21ms/step - loss: 0.0670 - acc: 0.9809 - val_loss: 2.6330 - val_acc: 0.3713
#
# Epoch 00085: val_acc did not improve
# Epoch 86/100
# 2089/2089 [==============================] - 46s 22ms/step - loss: 0.0675 - acc: 0.9823 - val_loss: 2.6179 - val_acc: 0.3767
#
# Epoch 00086: val_acc did not improve
# Epoch 87/100
# 2089/2089 [==============================] - 44s 21ms/step - loss: 0.0744 - acc: 0.9780 - val_loss: 2.6895 - val_acc: 0.3713
#
# Epoch 00087: val_acc did not improve
# Epoch 88/100
# 2089/2089 [==============================] - 44s 21ms/step - loss: 0.0569 - acc: 0.9861 - val_loss: 2.7175 - val_acc: 0.3631
#
# Epoch 00088: val_acc did not improve
# Epoch 89/100
# 2089/2089 [==============================] - 46s 22ms/step - loss: 0.0553 - acc: 0.9866 - val_loss: 2.6980 - val_acc: 0.3686
#
# Epoch 00089: val_acc did not improve
# Epoch 90/100
# 2089/2089 [==============================] - 43s 21ms/step - loss: 0.0481 - acc: 0.9885 - val_loss: 2.7038 - val_acc: 0.3577
#
# Epoch 00090: val_acc did not improve
# Epoch 91/100
# 2089/2089 [==============================] - 46s 22ms/step - loss: 0.0550 - acc: 0.9847 - val_loss: 2.6718 - val_acc: 0.3740
#
# Epoch 00091: val_acc did not improve
# Epoch 92/100
# 2089/2089 [==============================] - 44s 21ms/step - loss: 0.0586 - acc: 0.9823 - val_loss: 2.7317 - val_acc: 0.3713
#
# Epoch 00092: val_acc did not improve
# Epoch 93/100
# 2089/2089 [==============================] - 43s 21ms/step - loss: 0.0518 - acc: 0.9876 - val_loss: 2.7900 - val_acc: 0.3631
#
# Epoch 00093: val_acc did not improve
# Epoch 94/100
# 2089/2089 [==============================] - 45s 22ms/step - loss: 0.0596 - acc: 0.9832 - val_loss: 2.8781 - val_acc: 0.3577
#
# Epoch 00094: val_acc did not improve
# Epoch 95/100
# 2089/2089 [==============================] - 43s 21ms/step - loss: 0.0565 - acc: 0.9828 - val_loss: 2.8554 - val_acc: 0.3767
#
# Epoch 00095: val_acc did not improve
# Epoch 96/100
# 2089/2089 [==============================] - 43s 21ms/step - loss: 0.0673 - acc: 0.9809 - val_loss: 2.9218 - val_acc: 0.3631
#
# Epoch 00096: val_acc did not improve
# Epoch 97/100
# 2089/2089 [==============================] - 45s 21ms/step - loss: 0.0536 - acc: 0.9842 - val_loss: 2.8692 - val_acc: 0.3848
#
# Epoch 00097: val_acc did not improve
# Epoch 98/100
# 2089/2089 [==============================] - 43s 21ms/step - loss: 0.0477 - acc: 0.9866 - val_loss: 2.9137 - val_acc: 0.3821
#
# Epoch 00098: val_acc did not improve
# Epoch 99/100
# 2089/2089 [==============================] - 44s 21ms/step - loss: 0.0516 - acc: 0.9861 - val_loss: 2.8833 - val_acc: 0.3740
#
# Epoch 00099: val_acc did not improve
# Epoch 100/100
# 2089/2089 [==============================] - 44s 21ms/step - loss: 0.0510 - acc: 0.9871 - val_loss: 2.9229 - val_acc: 0.3740
#
# Epoch 00100: val_acc did not improve

# %%
# list all data in history
print(history.history.keys())

# summarize history for accuracy
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# summarize history for loss
plt.plot(history.history['loss'],'o')
plt.plot(history.history['val_loss'],'o')
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()
# Out:
# dict_keys(['val_loss', 'val_acc', 'loss', 'acc'])

# %%
# evaluate model on entire training set
model = load_model('LSTM_model.hdf5')
model.evaluate(X_train_sub,y_train,batch_size=N_train)
# Out:
# 2458/2458 [==============================] - 18s 8ms/step
# [0.60377579927444458, 0.81122863292694092]

# %%
# evaluate model on test set
model.evaluate(X_test_sub,y_test,batch_size=N_test)
# Out:
# 100/100 [==============================] - 1s 9ms/step
# [1.4399468898773193, 0.46000000834465027]
