# %%
from keras.models import Sequential
from keras.layers import LSTM, GRU, Dense, Dropout, TimeDistributed, BatchNormalization, Flatten, Activation
from keras import regularizers
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.models import load_model
import numpy as np
import h5py
import matplotlib.pyplot as plt
from data_utils import get_data
from sklearn import preprocessing
from functools import reduce
from scipy.fftpack import dct, idct
from scipy import signal
# Out:
# Using TensorFlow backend.

# %%
# Load data from all .mat files, combine them, eliminate EOG signals, shuffle and 
# seperate training data, validation data and testing data.
# Also do mean subtraction on x.

data = get_data('project_datasets',num_validation=0, num_test=100, subtract_mean=False, subtract_axis=1,
                transpose=True)
for k in data.keys():
    print('{}: {} '.format(k, data[k].shape))
# Out:
# X_train: (2458, 1000, 22)
# y_train: (2458,)
# X_val: (0, 1000, 22)
# y_val: (0,)
# X_test: (100, 1000, 22)
# y_test: (100,)

# %%
# substract data from list
X_train = data.get('X_train')
y_train = data.get('y_train')
#X_val = data.get('X_val')
#y_val = data.get('y_val')
X_test = data.get('X_test')
y_test = data.get('y_test')

# get data dimension
N_train, T_train, C_train = data.get('X_train').shape
N_val, T_val, C_val = data.get('X_val').shape
N_test, T_test, C_test = data.get('X_test').shape

# add dummy zeros for y classification
lb = preprocessing.LabelBinarizer()
lb.fit([0, 1, 2, 3,])
lb.classes_
y_train = lb.transform(y_train)
if (N_val > 0): y_val = lb.transform(y_val)
y_test = lb.transform(y_test)

# %%
# Filtering through FFT(discrete cosine transform)

def filter(x, low=0, high=1, plot=False):
    N = x.shape[0]
    t = np.linspace(0,N,N)
    y = dct(x, norm='ortho')
    window = np.zeros(N)
    window[int(low*N):int(high*N)] = 1
    yr = idct(y*window, norm='ortho')
    sum(abs(x-yr)**2) / sum(abs(x)**2)
    if plot:
        plt.plot(t, x, '-b')
        plt.plot(t, yr, 'r')
    return x

# Filter band
low_freq = 0.02
high_freq = 0.4

for i in np.arange(N_train):
    for j in np.arange(C_train):
       X_train[i,:,j]= filter(X_train[i,:,j],low_freq,high_freq)
for i in np.arange(N_val):
    for j in arange(C_val):
       X_val[i,:,j]= filter(X_val[i,:,j],low_freq,high_freq)
    
for i in np.arange(N_test):
    for j in np.arange(C_test):
       X_test[i,:,j]= filter(X_test[i,:,j],low_freq,high_freq)

# %%
# Downsampling in time through FFT

t_sample = 400
X_train_sub = signal.resample(X_train,t_sample,axis=1)
if (N_val > 0): X_val_sub = signal.resample(X_val,t_sample,axis=1)
X_test_sub = signal.resample(X_test,t_sample,axis=1)

# show a downsampling example
plt.plot(np.linspace(0,1,T_train),X_train[5,:,5],'-b')
plt.plot(np.linspace(0,1,t_sample),X_train_sub[5,:,5],'-r')

# %%
print(X_train_sub.shape)
# Out:
# (2458, 400, 22)

# %%
# # normalize data across the time sequence dimension only
# scaler = preprocessing.MinMaxScaler()
# for i in range(N_train):
#     scaler.fit(X_train[i,:,:])
#     X_train[i,:,:] = scaler.transform(X_train[i,:,:])
    
# for i in range(N_val):
#     scaler.fit(X_val[i,:,:])
#     X_val[i,:,:] = scaler.transform(X_val[i,:,:])

# %%
# def downsample(data, mul=10, enableTrunc = False):
#     assert data.shape[0] % mul == 0 or  enableTrunc, "Can't downsample without data truncation.\
#                                                 \n Set another value of mul or set enableTrunc = True"
#     outdata = []
#     for i in range(data.shape[0]//mul):
#         outdata.append(np.mean(data[i*mul:(i+1)*mul,...], axis=0, keepdims=True))
#     outdata = reduce(lambda a,b: np.append(a,b,0), outdata)
    
#     return outdata
# span = 2
# X_train_sub = np.expand_dims(downsample(X_train[0,:,:], mul=span),axis=0)
# for n in np.arange(1,X_train.shape[0]):
#     X_train_sub = np.append(X_train_sub,
#                             np.expand_dims(downsample(X_train[n,:,:], mul=span),axis=0),axis=0)

# X_val_sub = np.expand_dims(downsample(X_val[0,:,:], mul=span),axis=0)
# for n in np.arange(1,X_val.shape[0]):
#     X_val_sub = np.append(X_val_sub,
#                             np.expand_dims(downsample(X_val[n,:,:], mul=span),axis=0),axis=0)

# print('X_train_sub: ', X_train_sub.shape)
# print('X_val_sub: ', X_val_sub.shape)

# %%
# Expected input shape: ([batch_size], timesteps, data_dim)
# Note that we have to provide the full batch_input_shape if the network is stateful.
# the sample of index i in batch k is the follow-up for the sample i in batch k-1.

# perhaps should try masking layer

data_dim = C_train
seq_split = 1 # Set to one when using FFT to down sample
seq_len = int(X_train_sub.shape[1]*seq_split)
timesteps = seq_len
num_classes = 4
batch_size = 200
num_epoch = 100

model = Sequential()
#1
model.add(LSTM(200, return_sequences=True, stateful=False,
          recurrent_dropout=0.5, dropout = 0.5, input_shape=(timesteps, data_dim)))

#2
model.add(LSTM(100, return_sequences=True, stateful=False,
          recurrent_dropout=0.5, dropout = 0.5))

#3
model.add(LSTM(50, return_sequences=True, stateful=False,
          recurrent_dropout=0.5, dropout = 0.5))
model.add(Flatten())

#4
model.add(Dense(100))
model.add(BatchNormalization(axis=-1))
model.add(Activation('relu'))
model.add(Dropout(0.5))

#5
model.add(Dense(num_classes, activation='softmax'))

model.compile(loss='categorical_crossentropy',
              optimizer='rmsprop',
              metrics=['accuracy'])

# define early stopping callback
earlystop = EarlyStopping(monitor='val_loss', min_delta=0.001, patience=70, mode='auto')

# saves the model weights after each epoch if the validation loss decreased
checkpointer = ModelCheckpoint(filepath='LSTM_model.hdf5', monitor='val_acc', verbose=1, save_best_only=True)

callbacks_list = [earlystop, checkpointer]

# %%
history = model.fit(X_train_sub[:,:seq_len,:], y_train,
                    batch_size=batch_size, epochs=num_epoch, shuffle=True,
                    validation_split = 0.15, callbacks=callbacks_list)
# Out:
# Train on 2089 samples, validate on 369 samples
# Epoch 1/100
# 2089/2089 [==============================] - 58s 28ms/step - loss: 1.8905 - acc: 0.2365 - val_loss: 1.3824 - val_acc: 0.3577
#
# Epoch 00001: val_acc improved from -inf to 0.35772, saving model to LSTM_model.hdf5
# Epoch 2/100
# 2089/2089 [==============================] - 68s 33ms/step - loss: 1.6929 - acc: 0.3011 - val_loss: 1.3464 - val_acc: 0.3523
#
# Epoch 00002: val_acc did not improve
# Epoch 3/100
# 2089/2089 [==============================] - 69s 33ms/step - loss: 1.6441 - acc: 0.2800 - val_loss: 1.4599 - val_acc: 0.3496
#
# Epoch 00003: val_acc did not improve
# Epoch 4/100
# 2089/2089 [==============================] - 66s 32ms/step - loss: 1.6001 - acc: 0.3045 - val_loss: 1.4573 - val_acc: 0.3577
#
# Epoch 00004: val_acc did not improve
# Epoch 5/100
# 2089/2089 [==============================] - 70s 34ms/step - loss: 1.5525 - acc: 0.3217 - val_loss: 1.4803 - val_acc: 0.3604
#
# Epoch 00005: val_acc improved from 0.35772 to 0.36043, saving model to LSTM_model.hdf5
# Epoch 6/100
# 2089/2089 [==============================] - 69s 33ms/step - loss: 1.5027 - acc: 0.3260 - val_loss: 1.4513 - val_acc: 0.3659
#
# Epoch 00006: val_acc improved from 0.36043 to 0.36585, saving model to LSTM_model.hdf5
# Epoch 7/100
# 2089/2089 [==============================] - 68s 33ms/step - loss: 1.4582 - acc: 0.3499 - val_loss: 1.5323 - val_acc: 0.3631
#
# Epoch 00007: val_acc did not improve
# Epoch 8/100
# 2089/2089 [==============================] - 69s 33ms/step - loss: 1.4508 - acc: 0.3528 - val_loss: 1.6011 - val_acc: 0.3740
#
# Epoch 00008: val_acc improved from 0.36585 to 0.37398, saving model to LSTM_model.hdf5
# Epoch 9/100
# 2089/2089 [==============================] - 68s 33ms/step - loss: 1.4215 - acc: 0.3514 - val_loss: 1.6204 - val_acc: 0.3794
#
# Epoch 00009: val_acc improved from 0.37398 to 0.37940, saving model to LSTM_model.hdf5
# Epoch 10/100
# 2089/2089 [==============================] - 71s 34ms/step - loss: 1.3759 - acc: 0.3734 - val_loss: 1.4722 - val_acc: 0.3984
#
# Epoch 00010: val_acc improved from 0.37940 to 0.39837, saving model to LSTM_model.hdf5
# Epoch 11/100
# 2089/2089 [==============================] - 66s 32ms/step - loss: 1.3546 - acc: 0.3849 - val_loss: 1.4663 - val_acc: 0.3957
#
# Epoch 00011: val_acc did not improve
# Epoch 12/100
# 2089/2089 [==============================] - 70s 33ms/step - loss: 1.3444 - acc: 0.3988 - val_loss: 1.4671 - val_acc: 0.3740
#
# Epoch 00012: val_acc did not improve
# Epoch 13/100
# 2089/2089 [==============================] - 68s 32ms/step - loss: 1.3297 - acc: 0.4007 - val_loss: 1.4885 - val_acc: 0.3848
#
# Epoch 00013: val_acc did not improve
# Epoch 14/100
# 2089/2089 [==============================] - 68s 32ms/step - loss: 1.2982 - acc: 0.4222 - val_loss: 1.4319 - val_acc: 0.3902
#
# Epoch 00014: val_acc did not improve
# Epoch 15/100
# 2089/2089 [==============================] - 68s 33ms/step - loss: 1.2660 - acc: 0.4260 - val_loss: 1.5097 - val_acc: 0.3875
#
# Epoch 00015: val_acc did not improve
# Epoch 16/100
# 2089/2089 [==============================] - 67s 32ms/step - loss: 1.2596 - acc: 0.4390 - val_loss: 1.4442 - val_acc: 0.4065
#
# Epoch 00016: val_acc improved from 0.39837 to 0.40650, saving model to LSTM_model.hdf5
# Epoch 17/100
# 2089/2089 [==============================] - 70s 34ms/step - loss: 1.2211 - acc: 0.4562 - val_loss: 1.4613 - val_acc: 0.4038
#
# Epoch 00017: val_acc did not improve
# Epoch 18/100
# 2089/2089 [==============================] - 66s 32ms/step - loss: 1.1877 - acc: 0.4782 - val_loss: 1.4363 - val_acc: 0.4065
#
# Epoch 00018: val_acc improved from 0.40650 to 0.40650, saving model to LSTM_model.hdf5
# Epoch 19/100
# 2089/2089 [==============================] - 71s 34ms/step - loss: 1.1884 - acc: 0.4629 - val_loss: 1.4801 - val_acc: 0.4011
#
# Epoch 00019: val_acc did not improve
# Epoch 20/100
# 2089/2089 [==============================] - 67s 32ms/step - loss: 1.1487 - acc: 0.4955 - val_loss: 1.4661 - val_acc: 0.4065
#
# Epoch 00020: val_acc did not improve
# Epoch 21/100
# 2089/2089 [==============================] - 67s 32ms/step - loss: 1.1417 - acc: 0.4969 - val_loss: 1.4483 - val_acc: 0.4146
#
# Epoch 00021: val_acc improved from 0.40650 to 0.41463, saving model to LSTM_model.hdf5
# Epoch 22/100
# 2089/2089 [==============================] - 67s 32ms/step - loss: 1.1220 - acc: 0.5074 - val_loss: 1.4382 - val_acc: 0.4065
#
# Epoch 00022: val_acc did not improve
# Epoch 23/100
# 2089/2089 [==============================] - 68s 33ms/step - loss: 1.1032 - acc: 0.5232 - val_loss: 1.3987 - val_acc: 0.4228
#
# Epoch 00023: val_acc improved from 0.41463 to 0.42276, saving model to LSTM_model.hdf5
# Epoch 24/100
# 2089/2089 [==============================] - 70s 33ms/step - loss: 1.0937 - acc: 0.5223 - val_loss: 1.3584 - val_acc: 0.4363
#
# Epoch 00024: val_acc improved from 0.42276 to 0.43631, saving model to LSTM_model.hdf5
# Epoch 25/100
# 2089/2089 [==============================] - 66s 31ms/step - loss: 1.0764 - acc: 0.5323 - val_loss: 1.3671 - val_acc: 0.3984
#
# Epoch 00025: val_acc did not improve
# Epoch 26/100
# 2089/2089 [==============================] - 70s 34ms/step - loss: 1.0641 - acc: 0.5376 - val_loss: 1.3709 - val_acc: 0.4092
#
# Epoch 00026: val_acc did not improve
# Epoch 27/100
# 2089/2089 [==============================] - 67s 32ms/step - loss: 1.0428 - acc: 0.5606 - val_loss: 1.3537 - val_acc: 0.4282
#
# Epoch 00027: val_acc did not improve
# Epoch 28/100
# 2089/2089 [==============================] - 68s 33ms/step - loss: 1.0508 - acc: 0.5491 - val_loss: 1.3743 - val_acc: 0.4146
#
# Epoch 00028: val_acc did not improve
# Epoch 29/100
# 2089/2089 [==============================] - 67s 32ms/step - loss: 1.0024 - acc: 0.5802 - val_loss: 1.3431 - val_acc: 0.4119
#
# Epoch 00029: val_acc did not improve
# Epoch 30/100
# 2089/2089 [==============================] - 68s 33ms/step - loss: 1.0076 - acc: 0.5711 - val_loss: 1.3766 - val_acc: 0.4228
#
# Epoch 00030: val_acc did not improve
# Epoch 31/100
# 2089/2089 [==============================] - 68s 33ms/step - loss: 0.9753 - acc: 0.6003 - val_loss: 1.3544 - val_acc: 0.4282
#
# Epoch 00031: val_acc did not improve
# Epoch 32/100
# 2089/2089 [==============================] - 67s 32ms/step - loss: 0.9502 - acc: 0.6118 - val_loss: 1.3867 - val_acc: 0.4065
#
# Epoch 00032: val_acc did not improve
# Epoch 33/100
# 2089/2089 [==============================] - 70s 33ms/step - loss: 0.9456 - acc: 0.6218 - val_loss: 1.3384 - val_acc: 0.4065
#
# Epoch 00033: val_acc did not improve
# Epoch 34/100
# 2089/2089 [==============================] - 66s 32ms/step - loss: 0.9125 - acc: 0.6290 - val_loss: 1.3388 - val_acc: 0.4444
#
# Epoch 00034: val_acc improved from 0.43631 to 0.44444, saving model to LSTM_model.hdf5
# Epoch 35/100
# 2089/2089 [==============================] - 70s 33ms/step - loss: 0.8970 - acc: 0.6352 - val_loss: 1.3322 - val_acc: 0.4282
#
# Epoch 00035: val_acc did not improve
# Epoch 36/100
# 2089/2089 [==============================] - 68s 33ms/step - loss: 0.8700 - acc: 0.6529 - val_loss: 1.3144 - val_acc: 0.4363
#
# Epoch 00036: val_acc did not improve
# Epoch 37/100
# 2089/2089 [==============================] - 68s 32ms/step - loss: 0.8420 - acc: 0.6654 - val_loss: 1.2974 - val_acc: 0.4553
#
# Epoch 00037: val_acc improved from 0.44444 to 0.45528, saving model to LSTM_model.hdf5
# Epoch 38/100
# 2089/2089 [==============================] - 68s 32ms/step - loss: 0.8068 - acc: 0.6812 - val_loss: 1.3314 - val_acc: 0.4255
#
# Epoch 00038: val_acc did not improve
# Epoch 39/100
# 2089/2089 [==============================] - 68s 32ms/step - loss: 0.7942 - acc: 0.6970 - val_loss: 1.3183 - val_acc: 0.4526
#
# Epoch 00039: val_acc did not improve
# Epoch 40/100
# 2089/2089 [==============================] - 70s 33ms/step - loss: 0.7909 - acc: 0.6898 - val_loss: 1.3444 - val_acc: 0.4417
#
# Epoch 00040: val_acc did not improve
# Epoch 41/100
# 2089/2089 [==============================] - 65s 31ms/step - loss: 0.7617 - acc: 0.7075 - val_loss: 1.3399 - val_acc: 0.4309
#
# Epoch 00041: val_acc did not improve
# Epoch 42/100
# 2089/2089 [==============================] - 70s 33ms/step - loss: 0.7471 - acc: 0.7090 - val_loss: 1.3306 - val_acc: 0.4580
#
# Epoch 00042: val_acc improved from 0.45528 to 0.45799, saving model to LSTM_model.hdf5
# Epoch 43/100
# 2089/2089 [==============================] - 68s 33ms/step - loss: 0.7165 - acc: 0.7204 - val_loss: 1.3602 - val_acc: 0.4336
#
# Epoch 00043: val_acc did not improve
# Epoch 44/100
# 2089/2089 [==============================] - 68s 32ms/step - loss: 0.6800 - acc: 0.7367 - val_loss: 1.3556 - val_acc: 0.4526
#
# Epoch 00044: val_acc did not improve
# Epoch 45/100
# 2089/2089 [==============================] - 68s 32ms/step - loss: 0.6654 - acc: 0.7525 - val_loss: 1.3793 - val_acc: 0.4363
#
# Epoch 00045: val_acc did not improve
# Epoch 46/100
# 2089/2089 [==============================] - 67s 32ms/step - loss: 0.6444 - acc: 0.7578 - val_loss: 1.4020 - val_acc: 0.4255
#
# Epoch 00046: val_acc did not improve
# Epoch 47/100
# 2089/2089 [==============================] - 71s 34ms/step - loss: 0.6162 - acc: 0.7630 - val_loss: 1.4031 - val_acc: 0.4472
#
# Epoch 00047: val_acc did not improve
# Epoch 48/100
# 2089/2089 [==============================] - 65s 31ms/step - loss: 0.5867 - acc: 0.7908 - val_loss: 1.4571 - val_acc: 0.4173
#
# Epoch 00048: val_acc did not improve
# Epoch 49/100
# 2089/2089 [==============================] - 70s 33ms/step - loss: 0.5661 - acc: 0.7970 - val_loss: 1.4723 - val_acc: 0.4011
#
# Epoch 00049: val_acc did not improve
# Epoch 50/100
# 2089/2089 [==============================] - 67s 32ms/step - loss: 0.5450 - acc: 0.7985 - val_loss: 1.5164 - val_acc: 0.4011
#
# Epoch 00050: val_acc did not improve
# Epoch 51/100
# 2089/2089 [==============================] - 68s 32ms/step - loss: 0.5065 - acc: 0.8195 - val_loss: 1.4819 - val_acc: 0.4228
#
# Epoch 00051: val_acc did not improve
# Epoch 52/100
# 2089/2089 [==============================] - 67s 32ms/step - loss: 0.4937 - acc: 0.8315 - val_loss: 1.4733 - val_acc: 0.4390
#
# Epoch 00052: val_acc did not improve
# Epoch 53/100
# 2089/2089 [==============================] - 67s 32ms/step - loss: 0.4626 - acc: 0.8353 - val_loss: 1.4994 - val_acc: 0.4309
#
# Epoch 00053: val_acc did not improve
# Epoch 54/100
# 2089/2089 [==============================] - 70s 34ms/step - loss: 0.4733 - acc: 0.8387 - val_loss: 1.5320 - val_acc: 0.4255
#
# Epoch 00054: val_acc did not improve
# Epoch 55/100
# 2089/2089 [==============================] - 65s 31ms/step - loss: 0.4429 - acc: 0.8411 - val_loss: 1.5467 - val_acc: 0.4282
#
# Epoch 00055: val_acc did not improve
# Epoch 56/100
# 2089/2089 [==============================] - 70s 34ms/step - loss: 0.4304 - acc: 0.8521 - val_loss: 1.5784 - val_acc: 0.4309
#
# Epoch 00056: val_acc did not improve
# Epoch 57/100
# 2089/2089 [==============================] - 67s 32ms/step - loss: 0.3997 - acc: 0.8688 - val_loss: 1.6043 - val_acc: 0.4390
#
# Epoch 00057: val_acc did not improve
# Epoch 58/100
# 2089/2089 [==============================] - 68s 33ms/step - loss: 0.3690 - acc: 0.8794 - val_loss: 1.6113 - val_acc: 0.4499
#
# Epoch 00058: val_acc did not improve
# Epoch 59/100
# 2089/2089 [==============================] - 67s 32ms/step - loss: 0.3768 - acc: 0.8765 - val_loss: 1.6011 - val_acc: 0.4472
#
# Epoch 00059: val_acc did not improve
# Epoch 60/100
# 2089/2089 [==============================] - 67s 32ms/step - loss: 0.3450 - acc: 0.8822 - val_loss: 1.6525 - val_acc: 0.4282
#
# Epoch 00060: val_acc did not improve
# Epoch 61/100
# 2089/2089 [==============================] - 39s 18ms/step - loss: 0.3348 - acc: 0.8865 - val_loss: 1.6555 - val_acc: 0.4417
#
# Epoch 00061: val_acc did not improve
# Epoch 62/100
# 2089/2089 [==============================] - 29s 14ms/step - loss: 0.3130 - acc: 0.8990 - val_loss: 1.6793 - val_acc: 0.4417
#
# Epoch 00062: val_acc did not improve
# Epoch 63/100
# 2089/2089 [==============================] - 30s 15ms/step - loss: 0.3045 - acc: 0.8990 - val_loss: 1.6921 - val_acc: 0.4444
#
# Epoch 00063: val_acc did not improve
# Epoch 64/100
# 2089/2089 [==============================] - 29s 14ms/step - loss: 0.2832 - acc: 0.9067 - val_loss: 1.7136 - val_acc: 0.4390
#
# Epoch 00064: val_acc did not improve
# Epoch 65/100
# 2089/2089 [==============================] - 30s 14ms/step - loss: 0.2717 - acc: 0.9105 - val_loss: 1.7640 - val_acc: 0.4146
#
# Epoch 00065: val_acc did not improve
# Epoch 66/100
# 2089/2089 [==============================] - 29s 14ms/step - loss: 0.2521 - acc: 0.9239 - val_loss: 1.7991 - val_acc: 0.4255
#
# Epoch 00066: val_acc did not improve
# Epoch 67/100
# 2089/2089 [==============================] - 29s 14ms/step - loss: 0.2564 - acc: 0.9114 - val_loss: 1.8104 - val_acc: 0.4228
#
# Epoch 00067: val_acc did not improve
# Epoch 68/100
# 2089/2089 [==============================] - 29s 14ms/step - loss: 0.2433 - acc: 0.9225 - val_loss: 1.8346 - val_acc: 0.4146
#
# Epoch 00068: val_acc did not improve
# Epoch 69/100
# 2089/2089 [==============================] - 29s 14ms/step - loss: 0.2244 - acc: 0.9349 - val_loss: 1.8778 - val_acc: 0.4282
#
# Epoch 00069: val_acc did not improve
# Epoch 70/100
# 2089/2089 [==============================] - 30s 14ms/step - loss: 0.1991 - acc: 0.9454 - val_loss: 1.8907 - val_acc: 0.4336
#
# Epoch 00070: val_acc did not improve
# Epoch 71/100
# 2089/2089 [==============================] - 29s 14ms/step - loss: 0.2020 - acc: 0.9402 - val_loss: 1.8600 - val_acc: 0.4173
#
# Epoch 00071: val_acc did not improve
# Epoch 72/100
# 2089/2089 [==============================] - 29s 14ms/step - loss: 0.1850 - acc: 0.9426 - val_loss: 1.9753 - val_acc: 0.4092
#
# Epoch 00072: val_acc did not improve
# Epoch 73/100
# 2089/2089 [==============================] - 29s 14ms/step - loss: 0.1949 - acc: 0.9402 - val_loss: 1.9548 - val_acc: 0.4390
#
# Epoch 00073: val_acc did not improve
# Epoch 74/100
# 2089/2089 [==============================] - 30s 15ms/step - loss: 0.1698 - acc: 0.9493 - val_loss: 1.9800 - val_acc: 0.4390
#
# Epoch 00074: val_acc did not improve
# Epoch 75/100
# 2089/2089 [==============================] - 28s 14ms/step - loss: 0.1689 - acc: 0.9536 - val_loss: 2.0501 - val_acc: 0.4092
#
# Epoch 00075: val_acc did not improve
# Epoch 76/100
# 2089/2089 [==============================] - 29s 14ms/step - loss: 0.1677 - acc: 0.9493 - val_loss: 2.0201 - val_acc: 0.4282
#
# Epoch 00076: val_acc did not improve
# Epoch 77/100
# 2089/2089 [==============================] - 29s 14ms/step - loss: 0.1491 - acc: 0.9612 - val_loss: 2.0658 - val_acc: 0.4282
#
# Epoch 00077: val_acc did not improve
# Epoch 78/100
# 2089/2089 [==============================] - 30s 15ms/step - loss: 0.1624 - acc: 0.9517 - val_loss: 2.1363 - val_acc: 0.4092
#
# Epoch 00078: val_acc did not improve
# Epoch 79/100
# 2089/2089 [==============================] - 29s 14ms/step - loss: 0.1709 - acc: 0.9416 - val_loss: 2.1324 - val_acc: 0.4119
#
# Epoch 00079: val_acc did not improve
# Epoch 80/100
# 2089/2089 [==============================] - 29s 14ms/step - loss: 0.1409 - acc: 0.9584 - val_loss: 2.1612 - val_acc: 0.4309
#
# Epoch 00080: val_acc did not improve
# Epoch 81/100
# 2089/2089 [==============================] - 28s 14ms/step - loss: 0.1406 - acc: 0.9579 - val_loss: 2.1707 - val_acc: 0.4282
#
# Epoch 00081: val_acc did not improve
# Epoch 82/100
# 2089/2089 [==============================] - 30s 15ms/step - loss: 0.1304 - acc: 0.9588 - val_loss: 2.2193 - val_acc: 0.4309
#
# Epoch 00082: val_acc did not improve
# Epoch 83/100
# 2089/2089 [==============================] - 28s 14ms/step - loss: 0.1276 - acc: 0.9622 - val_loss: 2.2890 - val_acc: 0.4282
#
# Epoch 00083: val_acc did not improve
# Epoch 84/100
# 2089/2089 [==============================] - 29s 14ms/step - loss: 0.1142 - acc: 0.9655 - val_loss: 2.2956 - val_acc: 0.4255
#
# Epoch 00084: val_acc did not improve
# Epoch 85/100
# 2089/2089 [==============================] - 28s 14ms/step - loss: 0.1127 - acc: 0.9670 - val_loss: 2.2981 - val_acc: 0.4472
#
# Epoch 00085: val_acc did not improve
# Epoch 86/100
# 2089/2089 [==============================] - 30s 14ms/step - loss: 0.1122 - acc: 0.9703 - val_loss: 2.3520 - val_acc: 0.4255
#
# Epoch 00086: val_acc did not improve
# Epoch 87/100
# 2089/2089 [==============================] - 29s 14ms/step - loss: 0.1096 - acc: 0.9684 - val_loss: 2.3910 - val_acc: 0.4119
#
# Epoch 00087: val_acc did not improve
# Epoch 88/100
# 2089/2089 [==============================] - 29s 14ms/step - loss: 0.1064 - acc: 0.9698 - val_loss: 2.3479 - val_acc: 0.4201
#
# Epoch 00088: val_acc did not improve
# Epoch 89/100
# 2089/2089 [==============================] - 29s 14ms/step - loss: 0.1041 - acc: 0.9674 - val_loss: 2.4521 - val_acc: 0.4146
# Epoch 00089: val_acc did not improve
# Epoch 90/100
# 2089/2089 [==============================] - 30s 15ms/step - loss: 0.1016 - acc: 0.9713 - val_loss: 2.4432 - val_acc: 0.4201
#
# Epoch 00090: val_acc did not improve
# Epoch 91/100
# 2089/2089 [==============================] - 29s 14ms/step - loss: 0.0967 - acc: 0.9732 - val_loss: 2.4381 - val_acc: 0.4309
#
# Epoch 00091: val_acc did not improve
# Epoch 92/100
# 2089/2089 [==============================] - 29s 14ms/step - loss: 0.0908 - acc: 0.9732 - val_loss: 2.5130 - val_acc: 0.4255
#
# Epoch 00092: val_acc did not improve
# Epoch 93/100
# 2089/2089 [==============================] - 29s 14ms/step - loss: 0.0965 - acc: 0.9718 - val_loss: 2.5551 - val_acc: 0.4038
#
# Epoch 00093: val_acc did not improve
# Epoch 94/100
# 2089/2089 [==============================] - 30s 14ms/step - loss: 0.0807 - acc: 0.9775 - val_loss: 2.5027 - val_acc: 0.4282
#
# Epoch 00094: val_acc did not improve
# Epoch 95/100
# 2089/2089 [==============================] - 29s 14ms/step - loss: 0.0755 - acc: 0.9809 - val_loss: 2.5736 - val_acc: 0.4092
#
# Epoch 00095: val_acc did not improve
# Epoch 96/100
# 2089/2089 [==============================] - 29s 14ms/step - loss: 0.0787 - acc: 0.9789 - val_loss: 2.5982 - val_acc: 0.4092
#
# Epoch 00096: val_acc did not improve
# Epoch 97/100
# 2089/2089 [==============================] - 29s 14ms/step - loss: 0.0825 - acc: 0.9761 - val_loss: 2.5541 - val_acc: 0.4092
#
# Epoch 00097: val_acc did not improve
# Epoch 98/100
# 2089/2089 [==============================] - 30s 14ms/step - loss: 0.0681 - acc: 0.9804 - val_loss: 2.5690 - val_acc: 0.4201
#
# Epoch 00098: val_acc did not improve
# Epoch 99/100
# 2089/2089 [==============================] - 29s 14ms/step - loss: 0.0794 - acc: 0.9770 - val_loss: 2.6425 - val_acc: 0.4146
#
# Epoch 00099: val_acc did not improve
# Epoch 100/100
# 2089/2089 [==============================] - 29s 14ms/step - loss: 0.0749 - acc: 0.9765 - val_loss: 2.6983 - val_acc: 0.4146
#
# Epoch 00100: val_acc did not improve

# %%
# list all data in history
print(history.history.keys())

# summarize history for accuracy
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# summarize history for loss
plt.plot(history.history['loss'],'o')
plt.plot(history.history['val_loss'],'o')
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()
# Out:
# dict_keys(['val_loss', 'val_acc', 'loss', 'acc'])

# %%
# evaluate model on entire training set
model = load_model('LSTM_model.hdf5')
model.evaluate(X_train_sub,y_train,batch_size=N_train)
# Out:
# 2458/2458 [==============================] - 12s 5ms/step
# [0.52737891674041748, 0.84052073955535889]

# %%
# evaluate model on test set
model.evaluate(X_test_sub,y_test,batch_size=N_test)
# Out:
# 100/100 [==============================] - 0s 4ms/step
# [1.3251016139984131, 0.52999997138977051]
